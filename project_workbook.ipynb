js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-42F1hQV3NmnK/aikw++ctbC9ROw0br5kTb10r+K6Rp00mauyZMH5uZSH7996vSqNKUjfeacx4dxbNfxZ3ebhxQ==" src="https://github.githubassets.com/assets/repositories-e3617585.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-5VS9txZOv3EOORFwDsEW5xPehMoVpb3tjrCYKqB6a0uAXGb8ZEa7AO2m0SLYFWh29wlXJyIHrMdi9YKaKpN2vw==" src="https://github.githubassets.com/assets/topic-suggestions-e554bdb7.js" type="application/javascript"></script>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-Y9QCffkHDk3/KAoYUMhKeokbNlXWgpO+53XrccRwhUWzMTxEmhnp1ce7OVWP3vOzhCfWaxxnKWW9eVjjny8nRA==" src="https://github.githubassets.com/assets/code-menu-63d4027d.js" type="application/javascript"></script>
# <meta content="width=device-width" name="viewport"/>
# <title>GitHub - freeCodeCamp/freeCodeCamp: freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free.</title>
# <meta content="freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free. - GitHub - freeCodeCamp/freeCodeCamp: freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free." name="description"/>
# <link href="/opensearch.xml" rel="search" title="GitHub" type="application/opensearchdescription+xml"/>
# <link href="https://github.com/fluidicon.png" rel="fluid-icon" title="GitHub"/>
# <meta content="1401488693436528" property="fb:app_id"/>
# <meta content="app-id=1477376905" name="apple-itunes-app"/>
# <meta content="https://opengraph.githubassets.com/4f582d3b3b43ac6fc09b002d79e5fe8d0fedb61938affebef8e9a89efe7c94d1/freeCodeCamp/freeCodeCamp" name="twitter:image:src"/><meta content="@github" name="twitter:site"/><meta content="summary_large_image" name="twitter:card"/><meta content="GitHub - freeCodeCamp/freeCodeCamp: freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free." name="twitter:title"/><meta content="freeCodeCamp.org&amp;amp;#39;s open-source codebase and curriculum. Learn to code for free. - GitHub - freeCodeCamp/freeCodeCamp: freeCodeCamp.org&amp;amp;#39;s open-source codebase and curriculum. Learn t..." name="twitter:description"/>
# <meta content="https://opengraph.githubassets.com/4f582d3b3b43ac6fc09b002d79e5fe8d0fedb61938affebef8e9a89efe7c94d1/freeCodeCamp/freeCodeCamp" property="og:image"/><meta content="freeCodeCamp.org&amp;#39;s open-source codebase and curriculum. Learn to code for free. - GitHub - freeCodeCamp/freeCodeCamp: freeCodeCamp.org&amp;#39;s open-source codebase and curriculum. Learn to code f..." property="og:image:alt"/><meta content="1200" property="og:image:width"/><meta content="600" property="og:image:height"/><meta content="GitHub" property="og:site_name"/><meta content="object" property="og:type"/><meta content="GitHub - freeCodeCamp/freeCodeCamp: freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free." property="og:title"/><meta content="https://github.com/freeCodeCamp/freeCodeCamp" property="og:url"/><meta content="freeCodeCamp.org&amp;#39;s open-source codebase and curriculum. Learn to code for free. - GitHub - freeCodeCamp/freeCodeCamp: freeCodeCamp.org&amp;#39;s open-source codebase and curriculum. Learn to code f..." property="og:description"/>
# <link href="https://github.githubassets.com/" rel="assets"/>
# <meta content="E79E:25C9:31FB:5314:61FDAA93" data-pjax-transient="true" name="request-id"/><meta content="d448ce2eb70d9c0a98b262de404f228d3c3cc35cf0f6c68e90ccf40cf71d693c" data-pjax-transient="true" name="html-safe-nonce"/><meta content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJFNzlFOjI1Qzk6MzFGQjo1MzE0OjYxRkRBQTkzIiwidmlzaXRvcl9pZCI6IjIwODkxMzY0MjAxNDM2MDY0MTkiLCJyZWdpb25fZWRnZSI6ImlhZCIsInJlZ2lvbl9yZW5kZXIiOiJpYWQifQ==" data-pjax-transient="true" name="visitor-payload"/><meta content="9896ad73b20405e6bc8666616c360d80b4a55be89b92a1d1671aace082bfb450" data-pjax-transient="true" name="visitor-hmac"/>
# <meta content="repository:28457823" data-pjax-transient="" name="hovercard-subject-tag"/>
# <meta content="repository" data-pjax-transient="true" name="github-keyboard-shortcuts"/>
# <meta data-pjax-transient="" name="selected-link" value="repo_source"/>
# <meta content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY" name="google-site-verification"/>
# <meta content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU" name="google-site-verification"/>
# <meta content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA" name="google-site-verification"/>
# <meta content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc" name="google-site-verification"/>
# <meta content="https://collector.github.com/github/collect" name="octolytics-url"/>
# <meta content="/&lt;user-name&gt;/&lt;repo-name&gt;" data-pjax-transient="true" name="analytics-location"/>
# <meta content='{"version": "4", "rollouts": [], "typedAudiences": [], "anonymizeIP": true, "projectId": "16737760170", "variables": [], "featureFlags": [], "experiments": [{"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "20438636352", "key": "control"}, {"variables": [], "id": "20484957397", "key": "treatment"}], "id": "20479227424", "key": "growth_ghec_onboarding_experience", "layerId": "20467848595", "trafficAllocation": [{"entityId": "20484957397", "endOfRange": 1000}, {"entityId": "20484957397", "endOfRange": 3000}, {"entityId": "20484957397", "endOfRange": 5000}, {"entityId": "20484957397", "endOfRange": 6000}, {"entityId": "20484957397", "endOfRange": 8000}, {"entityId": "20484957397", "endOfRange": 10000}], "forcedVariations": {"85e2238ce2b9074907d7a3d91d6feeae": "control"}}, {"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "20667381018", "key": "control"}, {"variables": [], "id": "20680930759", "key": "treatment"}], "id": "20652570897", "key": "project_genesis", "layerId": "20672300363", "trafficAllocation": [{"entityId": "20667381018", "endOfRange": 5000}, {"entityId": "20680930759", "endOfRange": 10000}], "forcedVariations": {"83356e17066d336d1803024138ecb683": "treatment", "18e31c8a9b2271332466133162a4aa0d": "treatment", "10f8ab3fbc5ebe989a36a05f79d48f32": "treatment", "1686089f6d540cd2deeaec60ee43ecf7": "treatment"}}, {"status": "Running", "audienceIds": [], "variations": [{"variables": [], "id": "20898546114", "key": "control"}, {"variables": [], "id": "20923036705", "key": "treatment_a"}, {"variables": [], "id": "20965581308", "key": "treatment_b"}], "id": "20902325119", "key": "contact_sales_page_optimizations", "layerId": "20969031091", "trafficAllocation": [{"entityId": "20965581308", "endOfRange": 3330}, {"entityId": "20898546114", "endOfRange": 5000}, {"entityId": "20898546114", "endOfRange": 6670}, {"entityId": "20923036705", "endOfRange": 10000}], "forcedVariations": {}}], "audiences": [{"conditions": "[\"or\", {\"match\": \"exact\", \"name\": \"$opt_dummy_attribute\", \"type\": \"custom_attribute\", \"value\": \"$opt_dummy_value\"}]", "id": "$opt_dummy_audience", "name": "Optimizely-Generated Audience for Backwards Compatibility"}], "groups": [], "sdkKey": "WTc6awnGuYDdG98CYRban", "environmentKey": "production", "attributes": [{"id": "16822470375", "key": "user_id"}, {"id": "17143601254", "key": "spammy"}, {"id": "18175660309", "key": "organization_plan"}, {"id": "18813001570", "key": "is_logged_in"}, {"id": "19073851829", "key": "geo"}, {"id": "20175462351", "key": "requestedCurrency"}, {"id": "20785470195", "key": "country_code"}], "botFiltering": false, "accountId": "16737760170", "events": [{"experimentIds": [], "id": "17911811441", "key": "hydro_click.dashboard.teacher_toolbox_cta"}, {"experimentIds": [], "id": "18124116703", "key": "submit.organizations.complete_sign_up"}, {"experimentIds": [], "id": "18145892387", "key": "no_metric.tracked_outside_of_optimizely"}, {"experimentIds": [], "id": "18178755568", "key": "click.org_onboarding_checklist.add_repo"}, {"experimentIds": [], "id": "18180553241", "key": "submit.repository_imports.create"}, {"experimentIds": [], "id": "18186103728", "key": "click.help.learn_more_about_repository_creation"}, {"experimentIds": [], "id": "18188530140", "key": "test_event.do_not_use_in_production"}, {"experimentIds": [], "id": "18191963644", "key": "click.empty_org_repo_cta.transfer_repository"}, {"experimentIds": [], "id": "18195612788", "key": "click.empty_org_repo_cta.import_repository"}, {"experimentIds": [], "id": "18210945499", "key": "click.org_onboarding_checklist.invite_members"}, {"experimentIds": [], "id": "18211063248", "key": "click.empty_org_repo_cta.create_repository"}, {"experimentIds": [], "id": "18215721889", "key": "click.org_onboarding_checklist.update_profile"}, {"experimentIds": [], "id": "18224360785", "key": "click.org_onboarding_checklist.dismiss"}, {"experimentIds": [], "id": "182 ...
# <!-- To prevent page flashing, the optimizely JS needs to be loaded in the
#     <head> tag before the DOM renders -->
# <script crossorigin="anonymous" defer="defer" integrity="sha512-vMFEXzNkwSH209UPGY/WHYspQK2Yp8bM5Gni8x2XcNAvcO8oWKfeiY0DypdZBoKYTvBQOMZFnTIJxU7wyEEXfg==" src="https://github.githubassets.com/assets/optimizely-bcc1445f.js" type="application/javascript"></script>
# <meta content="github.com" name="hostname"/>
# <meta content="" name="user-login"/>
# <meta content="github.com" name="expected-hostname"/>
# <meta content="BIDIRECTIONAL_PREVIEWABLE_COMMENTS,MARKETPLACE_PENDING_INSTALLATIONS" name="enabled-features"/>
# <meta content="0f79f0778801756d675ddb2f8a73bfacf93c3e0b632c5c03d1662cf09bc25efc" data-turbo-track="reload" http-equiv="x-pjax-version"/>
# <meta content="ad743a89372c421844ffcba4fd906096b07b7fd7c2a57617ff2d2f0fdf463e56" data-turbo-track="reload" http-equiv="x-pjax-csp-version"/>
# <meta content="6e83a88eaa4a8611b9f8448f3a1f6f91dadf4c3f7e8d1aec9473307b6cd2ef95" data-turbo-track="reload" http-equiv="x-pjax-css-version"/>
# <meta content="1030d7559850e0eb66f03756c1ad2006968c4cbe8a87594ef3e86a0f5826fd02" data-turbo-track="reload" http-equiv="x-pjax-js-version"/>
# <meta content="github.com/freeCodeCamp/freeCodeCamp git https://github.com/freeCodeCamp/freeCodeCamp.git" name="go-import"/>
# <meta content="9892522" name="octolytics-dimension-user_id"/><meta content="freeCodeCamp" name="octolytics-dimension-user_login"/><meta content="28457823" name="octolytics-dimension-repository_id"/><meta content="freeCodeCamp/freeCodeCamp" name="octolytics-dimension-repository_nwo"/><meta content="true" name="octolytics-dimension-repository_public"/><meta content="false" name="octolytics-dimension-repository_is_fork"/><meta content="28457823" name="octolytics-dimension-repository_network_root_id"/><meta content="freeCodeCamp/freeCodeCamp" name="octolytics-dimension-repository_network_root_nwo"/>
# <link data-pjax-transient="" href="https://github.com/freeCodeCamp/freeCodeCamp" rel="canonical"/>
# <meta content="https://api.github.com/_private/browser/stats" name="browser-stats-url"/>
# <meta content="https://api.github.com/_private/browser/errors" name="browser-errors-url"/>
# <meta content="https://api.github.com/_private/browser/optimizely_client/errors" name="browser-optimizely-client-errors-url"/>
# <link color="#000000" href="https://github.githubassets.com/pinned-octocat.svg" rel="mask-icon"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.png" rel="alternate icon" type="image/png"/>
# <link class="js-site-favicon" href="https://github.githubassets.com/favicons/favicon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#1e2327" name="theme-color"/>
# <meta content="light dark" name="color-scheme"/>
# <link crossorigin="use-credentials" href="/manifest.json" rel="manifest"/>
# </head>
# <body class="logged-out env-production page-responsive" style="word-wrap: break-word;">
# <div class="position-relative js-header-wrapper">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-xl d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="3fc8ddba53115184759a047677a5efef9bd0d368a9057369f81cedfdd322e10a" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E&amp;source=header-repo">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# ...
# </a>
# </li>
# </ul>
# <div class="mt-3" data-view-component="true">
# <a data-view-component="true" href="/freeCodeCamp/freeCodeCamp/graphs/contributors" text="small">
#       + 4,378 contributors
# </a></div>
# </div>
# </div>
# <div class="BorderGrid-row">
# <div class="BorderGrid-cell">
# <h2 class="h4 mb-3">Languages</h2>
# <div class="mb-2">
# <span class="Progress" data-view-component="true">
# <span aria-label="JavaScript 47.7" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#f1e05a !important;;width: 47.7%;"></span>
# <span aria-label="TypeScript 45.9" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#2b7489 !important;;width: 45.9%;"></span>
# <span aria-label="CSS 6.0" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#563d7c !important;;width: 6.0%;"></span>
# <span aria-label="Shell 0.2" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#89e051 !important;;width: 0.2%;"></span>
# <span aria-label="EJS 0.1" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#a91e50 !important;;width: 0.1%;"></span>
# <span aria-label="Dockerfile 0.1" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#384d54 !important;;width: 0.1%;"></span>
# </span></div>
# <ul class="list-style-none">
# <li class="d-inline">
# <a class="d-inline-flex flex-items-center flex-nowrap Link--secondary no-underline text-small mr-3" data-ga-click="Repository, language stats search click, location:repo overview" href="/freeCodeCamp/freeCodeCamp/search?l=javascript">
# <svg aria-hidden="true" class="octicon octicon-dot-fill mr-2" data-view-component="true" height="16" style="color:#f1e05a;" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 4a4 4 0 100 8 4 4 0 000-8z" fill-rule="evenodd"></path>
# </svg>
# <span class="color-fg-default text-bold mr-1">JavaScript</span>
# <span>47.7%</span>
# </a>
# </li>
# <li class="d-inline">
# <a class="d-inline-flex flex-items-center flex-nowrap Link--secondary no-underline text-small mr-3" data-ga-click="Repository, language stats search click, location:repo overview" href="/freeCodeCamp/freeCodeCamp/search?l=typescript">
# <svg aria-hidden="true" class="octicon octicon-dot-fill mr-2" data-view-component="true" height="16" style="color:#2b7489;" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 4a4 4 0 100 8 4 4 0 000-8z" fill-rule="evenodd"></path>
# </svg>
# <span class="color-fg-default text-bold mr-1">TypeScript</span>
# <span>45.9%</span>
# </a>
# </li>
# <li class="d-inline">
# <a class="d-inline-flex flex-items-center flex-nowrap Link--secondary no-underline text-small mr-3" data-ga-click="Repository, language stats search click, location:repo overview" href="/freeCodeCamp/freeCodeCamp/search?l=css">
# <svg aria-hidden="true" class="octicon octicon-dot-fill mr-2" data-view-component="true" height="16" style="color:#563d7c;" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 4a4 4 0 100 8 4 4 0 000-8z" fill-rule="evenodd"></path>
# </svg>
# <span class="color-fg-default text-bold mr-1">CSS</span>
# <span>6.0%</span>
# </a>
# </li>
# <li class="d-inline">
# <a class="d-inline-flex flex-items-center flex-nowrap Link--secondary no-underline text-small mr-3" data-ga-click="Repository, language stats search click, location:repo overview" href="/freeCodeCamp/freeCodeCamp/search?l=shell">
# <svg aria-hidden="true" class="octicon octicon-dot-fill mr-2" data-view-component="true" height="16" style="color:#89e051;" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 4a4 4 0 100 8 4 4 0 000-8z" fill-rule="evenodd"></path>
# </svg>
# <span class="color-fg-default text-bold mr-1">Shell</span>
# <span>0.2%</span>
# </a>
# </li>
# <li class="d-inline">
# <a class="d-inline-flex flex-items-center flex-nowrap Link--secondary no-underline text-small mr-3" data-ga-click="Repository, language stats search click, location:repo overview" href="/freeCodeCamp/freeCodeCamp/search?l=ejs">
# <svg aria-hidden="true" class="octicon octicon-dot-fill mr-2" data-view-component="true" height="16" style="color:#a91e50;" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 4a4 4 0 100 8 4 4 0 000-8z" fill-rule="evenodd"></path>
# </svg>
# <span class="color-fg-default text-bold mr-1">EJS</span>
# <span>0.1%</span>
# </a>
# </li>
# <li class="d-inline">
# <a class="d-inline-flex flex-items-center flex-nowrap Link--secondary no-underline text-small mr-3" data-ga-click="Repository, language stats search click, location:repo overview" href="/freeCodeCamp/freeCodeCamp/search?l=dockerfile">
# <svg aria-hidden="true" class="octicon octicon-dot-fill mr-2" data-view-component="true" height="16" style="color:#384d54;" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 4a4 4 0 100 8 4 4 0 000-8z" fill-rule="evenodd"></path>
# </svg>
# <span class="color-fg-default text-bold mr-1">Dockerfile</span>
# <span>0.1%</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div></div>
# </div>
# </div>
# </main>
# </div>
# </div>
# <footer class="footer width-full container-xl p-responsive" role="contentinfo">
# <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <ul class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </li>
# </ul>
# <ul class="list-style-none d-flex flex-wrap col-12 col-lg-8 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to terms","label":"text:terms","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="24de3894530a5ad1171958cb758b839fc6d047261124f7a173a5f1b25041ebb1" href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to privacy","label":"text:privacy","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="78be9ed9e6787b611b2a36b44ba4394513ee380c258ae04cd269467f00cd44be" href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to security","label":"text:security","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="fd5f1e82baa274acc0cff3d9ac8ac05425cca62d6a4d299c16a386ac234aa725" href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to status","label":"text:status","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="3154e4f320a73d4659177358deb2aa8f5d99e76d0a799d4ca607b56bf6c78fd1" href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to contact","label":"text:contact","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="29494d69cd59fc3c940087dfdff71544c94de3f27004abc30588a8ac57231dae" href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to Pricing","label":"text:Pricing","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="13428d7579a3f952851d311c2d6d5ed5ac3964bdc9cd934fb5db848cc4972947" href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to api","label":"text:api","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="5a528bd19204d17d84c663270ac8fc7a1fb3bca410bdef5127cec316cd875778" href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to training","label":"text:training","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="f2a7247bb02450f477d9cb7ec5af6a83a2d9a1f0c95dbd72bb4d31c202b56525" href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' data-hydro-click='{"event_type":"analytics.event","payload":{"category":"Footer","action":"go to blog","label":"text:blog","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="1d807d73ad484036e8782be518f1eec2527afde3d5b46a1f980dc34a83671c70" href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </div>
# <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>
# </footer>
# <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>
# <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>
# <template id="site-details-dialog">
# <details class="details-reset details-overlay details-overlay-dark lh-default color-fg-default hx_rsm" open="">
# <summary aria-label="Close dialog" role="button"></summary>
# <details-dialog aria-labelledby="box-title" class="Box Box--overlay d-flex flex-column anim-fade-in fast hx_rsm-dialog hx_rsm-modal">
# <button aria-label="Close dialog" class="Box-btn-octicon m-0 btn-octicon position-absolute right-0 top-0" data-close-dialog="" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>
# </details-dialog>
# </details>
# </template>
# <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>
# <template id="snippet-clipboard-copy-button">
# <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>
# </template>
# </body>
# </html>

# %%
language = soup.select("span", class_ = "color-fg-default text-bold mr-1")
language
# Out:
# [<span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
#  <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
#  </span>,
#  <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>,
#  <span aria-label="in this repository" class="js-jump-to-badge-search-text-default d-none">
#          In this repository
#        </span>,
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>,
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span class="color-fg-muted">No suggested jump to results</span>,
#  <span aria-label="in this repository" class="js-jump-to-badge-search-text-default d-none">
#          In this repository
#        </span>,
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>,
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span aria-label="in this organization" class="js-jump-to-badge-search-text-default d-none">
#          In this organization
#        </span>,
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>,
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span aria-label="in this repository" class="js-jump-to-badge-search-text-default d-none">
#          In this repository
#        </span>,
#  <span aria-label="in all of GitHub" class="js-jump-to-badge-search-text-global d-none">
#          All GitHub
#        </span>,
#  <span aria-hidden="true" class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span class="d-inline-block ml-1 v-align-middle">↵</span>,
#  <span class="author flex-self-stretch" itemprop="author">
#  <a class="url fn" data-hovercard-type="organization" data-hovercard-url="/orgs/freeCodeCamp/hovercard" href="/freeCodeCamp" rel="author">freeCodeCamp</a>
#  </span>,
#  <span class="mx-1 flex-self-stretch color-fg-muted">/</span>,
#  <span></span>,
#  <span class="Label Label--secondary v-align-middle mr-1">Public</span>,
#  <span class="Counter" data-pjax-replace="true" data-view-component="true" id="repo-network-counter" title="27,895">27.9k</span>,
#  <span class="d-inline" data-view-component="true">
#            Star
#  </span>,
#  <span aria-label="339911 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="339,911">340k</span>,
#  <span class="flex-auto min-width-0 css-truncate css-truncate-target width-fit">
#  <a class="text-bold" href="https://contribute.freecodecamp.org" rel="noopener noreferrer" role="link" target="_blank" title="https://contribute.freecodecamp.org">contribute.freecodecamp.org</a>
#  </span>,
#  <span class="text-bold">340k</span>,
#  <span class="text-bold">27.9k</span>,
#  <span class="d-inline" data-view-component="true">
#            Star
#  </span>,
#  <span data-content="Code">Code</span>,
#  <span class="Counter" data-pjax-replace="" data-view-component="true" id="code-repo-tab-count" title="Not available"></span>,
#  <span data-content="Issues">Issues</span>,
#  <span class="Counter" data-pjax-replace="" data-view-component="true" id="issues-repo-tab-count" title="125">125</span>,
#  <span data-content="Pull requests">Pull requests</span>,
#  <span class="Counter" data-pjax-replace="" data-view-component="true" id="pull-requests-repo-tab-count" title="41">41</span>,
#  <span data-content="Actions">Actions</span>,
#  <span class="Counter" data-pjax-replace="" data-view-component="true" id="actions-repo-tab-count" title="Not available"></span>,
#  <span data-content="Security">Security</span>,
#  <span data-content="Insights">Insights</span>,
#  <span class="Counter" data-pjax-replace="" data-view-component="true" id="insights-repo-tab-count" title="Not available"></span>,
#  <span class="sr-only">More</span>,
#  <span class="css-truncate-target" data-menu-button="">main</span>,
#  <span class="dropdown-caret"></span>,
#  <span class="SelectMenu-title">Switch branches/tags</span>,
#  <span class="flex-1 css-truncate css-truncate-overflow {{ isFilteringClass }}">{{ refName }}</span>,
#  <span class="Label Label--secondary flex-self-start" hidden="{{ isNotDefault }}">default</span>,
#  <span class="flex-1 css-truncate css-truncate-overflow {{ isFilteringClass }}">{{ refName }}</span>,
#  <span class="Label Label--secondary flex-self-start" hidden="{{ isNotDefault }}">default</span>,
#  <span class="color-fg-muted">branches</span>,
#  <span class="color-fg-muted">tags</span>,
#  <span class="d-none d-md-flex ml-2">
#  <get-repo class="">
#  <details class="position-relative details-overlay details-reset js-codespaces-details-container" data-action="toggle:get-repo#onDetailsToggle">
#  <summary class="btn-primary btn" data-hydro-click='{"event_type":"repository.click","payload":{"repository_id":28457823,"target":"CLONE_OR_DOWNLOAD_BUTTON","originating_url":"https://github.com/freeCodeCamp/freeCodeCamp","user_id":null}}' data-hydro-click-hmac="4d714173c8e3343a2d324bbdbf3a1ec6bf247cbda97e32a01ebff825a2007435" data-view-component="true">  Code<span class="dropdown-caret"></span>
#  </summary> <div class="position-relative">
#  <div class="dropdown-menu dropdown-menu-sw p-0" style="top:6px;width:378px;">
#  <include-fragment src="/freeCodeCamp/freeCodeCamp/code_menu_contents/main">
#  <svg class="anim-rotate" data-view-component="true" fill="none" height="32" style="box-sizing: content-box; color: var(--color-icon-primary);" viewbox="0 0 16 16" width="32">
#  <circle cx="8" cy="8" r="7" stroke="currentColor" stroke-opacity="0.25" stroke-width="2" vector-effect="non-scaling-stroke"></circle>
#  <path d="M15 8a7.002 7.002 0 00-7-7" stroke="currentColor" stroke-linecap="round" stroke-width="2" vector-effect="non-scaling-stroke"></path>
#  </svg>
#  </include-fragment>
#  </div>
#  </div>
#  </details>
#  </get-repo>
#  </span>,
#  <span class="dropdown-caret"></span>,
#  <span class="d-none d-sm-inline">
#  <a class="Link--primary markdown-title" data-pjax="true" data-test-selector="commit-tease-commit-message" href="/freeCodeCamp/freeCodeCamp/commit/018f73e51835806e046d2105fa4204c939affe97" title="fix(deps): update dependency sanitize-html to v2.7.0">fix(deps): update dependency sanitize-html to v2.7.0</a>
#  </span>,
#  <span class="hidden-text-expander ml-2 d-inline-block d-inline-block d-lg-none">
#  <button aria-expanded="false" class="color-fg-default ellipsis-expander js-details-target" type="button">
#          …
#        </button>
#  </span>,
#  <span class="d-none d-sm-inline">
#  <strong>29,757</strong>
#  <span aria-label="Commits on main" class="color-fg-muted d-none d-lg-inline">
#                        commits
#                      </span>
#  </span>,
#  <span aria-label="Commits on main" class="color-fg-muted d-none d-lg-inline">
#                        commits
#                      </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/.github" title=".github">.github</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/a47610c0f059f5c394261641f72be7c1f179c441" title="fix(tools): autoclose syntax error (#44987)">fix(tools): autoclose syntax error (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44987/hovercard" data-id="1120382434" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44987" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44987">#44987</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/a47610c0f059f5c394261641f72be7c1f179c441" title="fix(tools): autoclose syntax error (#44987)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/.husky" title=".husky">.husky</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/fb3e9ef4206279814550dbd28ce37e4988bcfee0" title="chore(deps): update dependency husky to v7 (#42760)
#
#  Co-authored-by: Renovate Bot &lt;bot@renovateapp.com&gt;
#  Co-authored-by: Oliver Eyton-Williams &lt;ojeytonwilliams@gmail.com&gt;">chore(deps): update dependency husky to v7 (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/42760/hovercard" data-id="937726117" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/42760" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/42760">#42760</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/fb3e9ef4206279814550dbd28ce37e4988bcfee0" title="chore(deps): update dependency husky to v7 (#42760)
#
#  Co-authored-by: Renovate Bot &lt;bot@renovateapp.com&gt;
#  Co-authored-by: Oliver Eyton-Williams &lt;ojeytonwilliams@gmail.com&gt;">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/api-server" title="api-server">api-server</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7f027958afaffad865d599cce70e25992e325d86" title="chore: migrate to nanoid 3 (#44893)">chore: migrate to nanoid 3 (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44893/hovercard" data-id="1112931274" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44893" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44893">#44893</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7f027958afaffad865d599cce70e25992e325d86" title="chore: migrate to nanoid 3 (#44893)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/client" title="client">client</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/018f73e51835806e046d2105fa4204c939affe97" title="fix(deps): update dependency sanitize-html to v2.7.0">fix(deps): update dependency sanitize-html to v2.7.0</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/config" title="config">config</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/47d27412fab3d88219d4dc787ca8bfa56995b9e8" title='feat(learn, i18n): enable japanese certifications (#44869)
#
#  * feat(learn, i18n): enable japanese certifications
#
#  * feat(learn, i18n): update links for japanese pages
#
#  * Revert "feat(learn, i18n): update links for japanese pages"
#
#  This reverts commit 8e16f4dd22bf433f89285aa5a5d464d0e45d790a.
#
#  * feat(learn, i18n): update links for japanese pages
#
#  * feat(learn, i18n): update algoliaIndices for japanese
#
#  * feat(learn, i18n): update meta tags for japanese'>feat(learn, i18n): enable japanese certifications (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44869/hovercard" data-id="1110762439" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44869" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44869">#44869</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/47d27412fab3d88219d4dc787ca8bfa56995b9e8" title='feat(learn, i18n): enable japanese certifications (#44869)
#
#  * feat(learn, i18n): enable japanese certifications
#
#  * feat(learn, i18n): update links for japanese pages
#
#  * Revert "feat(learn, i18n): update links for japanese pages"
#
#  This reverts commit 8e16f4dd22bf433f89285aa5a5d464d0e45d790a.
#
#  * feat(learn, i18n): update links for japanese pages
#
#  * feat(learn, i18n): update algoliaIndices for japanese
#
#  * feat(learn, i18n): update meta tags for japanese'>)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/curriculum" title="curriculum">curriculum</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/f38d19132dd4c416f428084c32bfe37d1188247c" title="chore(i18n,learn): processed translations (#45001)">chore(i18n,learn): processed translations (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/45001/hovercard" data-id="1121889810" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/45001" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/45001">#45001</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/f38d19132dd4c416f428084c32bfe37d1188247c" title="chore(i18n,learn): processed translations (#45001)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/cypress" title="cypress">cypress</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/c541baf179ff4630fcf9b675ca04fbe224e8fb03" title="fix(client): update invalid stored code (#44437)
#
#  * fix: repair invalid stored code">fix(client): update invalid stored code (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44437/hovercard" data-id="1075524865" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44437" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44437">#44437</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/c541baf179ff4630fcf9b675ca04fbe224e8fb03" title="fix(client): update invalid stored code (#44437)
#
#  * fix: repair invalid stored code">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/docs" title="docs">docs</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/a2a1c62953bdc78373b582193b6fe24d74ec311f" title="chore(i18n,docs): processed translations (#44964)">chore(i18n,docs): processed translations (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44964/hovercard" data-id="1118198400" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44964" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44964">#44964</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/a2a1c62953bdc78373b582193b6fe24d74ec311f" title="chore(i18n,docs): processed translations (#44964)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/tools" title="tools">tools</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/044f0f927832c3ac4d2fbdb54a3c188267620062" title="chore(deps): update storybook monorepo to v6.4.18 (#45002)
#
#  Co-authored-by: Renovate Bot &lt;bot@renovateapp.com&gt;">chore(deps): update storybook monorepo to v6.4.18 (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/45002/hovercard" data-id="1121954866" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/45002" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/45002">#45002</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/044f0f927832c3ac4d2fbdb54a3c188267620062" title="chore(deps): update storybook monorepo to v6.4.18 (#45002)
#
#  Co-authored-by: Renovate Bot &lt;bot@renovateapp.com&gt;">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/tree/main/utils" title="utils">utils</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/cacc4eacd7df75a47df123d98217d46816a1bb8e" title="fix: handle the sorting of transformed files (#44724)
#
#  * fix: handle the sorting of transformed files
#
#  We can't use the ext property, since that is transformed, but the
#  history is maintained.
#
#  * test: make solutions polyVinyls for sorting
#
#  * refactor: inline prepareChallenge
#
#  * refactor: make solutions polys in getChallenges
#
#  * fix: convert each solution to a poly
#
#  * fix: skip empty solutions
#
#  * fix: get challenge file history in client
#
#  * refactor: stop calling isPoly from the client
#
#  * fix: remove debug console.log
#
#  * refactor: remove unnecessary sorting step">fix: handle the sorting of transformed files (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44724/hovercard" data-id="1096893461" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44724" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44724">#44724</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/cacc4eacd7df75a47df123d98217d46816a1bb8e" title="fix: handle the sorting of transformed files (#44724)
#
#  * fix: handle the sorting of transformed files
#
#  We can't use the ext property, since that is transformed, but the
#  history is maintained.
#
#  * test: make solutions polyVinyls for sorting
#
#  * refactor: inline prepareChallenge
#
#  * refactor: make solutions polys in getChallenges
#
#  * fix: convert each solution to a poly
#
#  * fix: skip empty solutions
#
#  * fix: get challenge file history in client
#
#  * refactor: stop calling isPoly from the client
#
#  * fix: remove debug console.log
#
#  * refactor: remove unnecessary sorting step">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.dockerignore" title=".dockerignore">.dockerignore</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/5d46e2830aff78ae4090028393fbe86c8ce29ef3" title="feat: add Docker build (#41187)
#
#  * feat(docker): build and use client and api images
#
#  * feat: always use .env
#
#  dotenv fails without throwing if the .env file is missing and never
#  overwrites variables if they already exist. As such, we can use it in
#  build pipelines.
#
#  * fix: remove quotes from env vars
#
#  dotenv normalises quoted and unquoted strings (X=x, X='x' and
#  X=&quot;x&quot;) all become the same .env object {X: 'x'}. However, Docker's
#  env_file does not (the three cases are distinct).  As a result, we
#  should use unquoted strings for consistency.
#
#  * fix: provide custom warning when .env is missing
#
#  * feat(docker): include client-config
#
#  * fix(docker): remove build packages from api image
#
#  * fix(docker): run script from correct dir
#
#  * fix(docker): correct permissions and dests
#
#  * fix(docker): consolidate run steps
#
#  This is standard practice, but did not have a noticable affect on the
#  image size
#
#  * fix(docker): clean the npm cache
#
#  Prior to this step the image was 1.11GB uncompressed and we got a modest
#  saving, 1.09GB after.
#
#  * refactor(docker): regexless COPY directives
#
#  * feat(docker): use alpine
#
#  This shrinks the image down to 259MB
#
#  * fix(docker): update build scripts
#
#  * fix: correct the server Dockerfile RUNs
#
#  * DEBUG: expose mysql port for seeding
#
#  * chore: update client Dockerfile's node versions
#
#  * fix: remove executable permissions from index.js
#
#  It's not a cli, so I don't think it needs to be executable.
#
#  * chore: update node and remove stale comments
#
#  * feat: use ENTRYPOINT + CMD to allow runtime config
#
#  * fix: add CURRICULUM_LOCALE arg
#
#  * feat: allow client port configuration
#
#  * feat: allow api port to be configured
#
#  * refactor: use unique variable names for ports
#
#  * fix: add default CLIENT_PORT
#
#  * refactor: clean up">feat: add Docker build (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/41187/hovercard" data-id="812116751" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/41187" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/41187">#41187</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/5d46e2830aff78ae4090028393fbe86c8ce29ef3" title="feat: add Docker build (#41187)
#
#  * feat(docker): build and use client and api images
#
#  * feat: always use .env
#
#  dotenv fails without throwing if the .env file is missing and never
#  overwrites variables if they already exist. As such, we can use it in
#  build pipelines.
#
#  * fix: remove quotes from env vars
#
#  dotenv normalises quoted and unquoted strings (X=x, X='x' and
#  X=&quot;x&quot;) all become the same .env object {X: 'x'}. However, Docker's
#  env_file does not (the three cases are distinct).  As a result, we
#  should use unquoted strings for consistency.
#
#  * fix: provide custom warning when .env is missing
#
#  * feat(docker): include client-config
#
#  * fix(docker): remove build packages from api image
#
#  * fix(docker): run script from correct dir
#
#  * fix(docker): correct permissions and dests
#
#  * fix(docker): consolidate run steps
#
#  This is standard practice, but did not have a noticable affect on the
#  image size
#
#  * fix(docker): clean the npm cache
#
#  Prior to this step the image was 1.11GB uncompressed and we got a modest
#  saving, 1.09GB after.
#
#  * refactor(docker): regexless COPY directives
#
#  * feat(docker): use alpine
#
#  This shrinks the image down to 259MB
#
#  * fix(docker): update build scripts
#
#  * fix: correct the server Dockerfile RUNs
#
#  * DEBUG: expose mysql port for seeding
#
#  * chore: update client Dockerfile's node versions
#
#  * fix: remove executable permissions from index.js
#
#  It's not a cli, so I don't think it needs to be executable.
#
#  * chore: update node and remove stale comments
#
#  * feat: use ENTRYPOINT + CMD to allow runtime config
#
#  * fix: add CURRICULUM_LOCALE arg
#
#  * feat: allow client port configuration
#
#  * feat: allow api port to be configured
#
#  * refactor: use unique variable names for ports
#
#  * fix: add default CLIENT_PORT
#
#  * refactor: clean up">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.editorconfig" title=".editorconfig">.editorconfig</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/0da9760d4e43ed9401c9449ab08523ec0a0fde7f" title="fix: Specify indent_size = 2 globally in .editorconfig. (#39236)">fix: Specify indent_size = 2 globally in .editorconfig. (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/39236/hovercard" data-id="655479188" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/39236" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/39236">#39236</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/0da9760d4e43ed9401c9449ab08523ec0a0fde7f" title="fix: Specify indent_size = 2 globally in .editorconfig. (#39236)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.eslintignore" title=".eslintignore">.eslintignore</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">refactor: organise TypeScript config and migrate helpers (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44747/hovercard" data-id="1099061205" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44747" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44747">#44747</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.eslintrc.json" title=".eslintrc.json">.eslintrc.json</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">refactor: organise TypeScript config and migrate helpers (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44747/hovercard" data-id="1099061205" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44747" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44747">#44747</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.gitattributes" title=".gitattributes">.gitattributes</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/0b2aac7bddc853cd341e9952a8a8cb3956cd461a" title="chore(tools): set git attributes for line endigs (#35298)">chore(tools): set git attributes for line endigs (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/35298/hovercard" data-id="411871223" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/35298" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/35298">#35298</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/0b2aac7bddc853cd341e9952a8a8cb3956cd461a" title="chore(tools): set git attributes for line endigs (#35298)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.gitignore" title=".gitignore">.gitignore</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">refactor: organise TypeScript config and migrate helpers (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44747/hovercard" data-id="1099061205" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44747" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44747">#44747</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.gitpod.yml" title=".gitpod.yml">.gitpod.yml</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">refactor: organise TypeScript config and migrate helpers (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44747/hovercard" data-id="1099061205" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44747" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44747">#44747</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.lintstagedrc.js" title=".lintstagedrc.js">.lintstagedrc.js</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/0a5c7cbfcfb27d056ccebabe862c69181279d3a9" title="fix(tools): stop multiple prettier runs on large commits (#44124)">fix(tools): stop multiple prettier runs on large commits (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44124/hovercard" data-id="1044916504" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44124" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44124">#44124</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/0a5c7cbfcfb27d056ccebabe862c69181279d3a9" title="fix(tools): stop multiple prettier runs on large commits (#44124)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.npmrc" title=".npmrc">.npmrc</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/6fef483946061c44d2b617d9ee04e9fb62420dcf" title="chore: update all packages to node v16 &amp; npm v8">chore: update all packages to node v16 &amp; npm v8</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.prettierignore" title=".prettierignore">.prettierignore</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">refactor: organise TypeScript config and migrate helpers (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44747/hovercard" data-id="1099061205" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44747" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44747">#44747</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/.prettierrc" title=".prettierrc">.prettierrc</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/6c91f81b0e3cdc0f6031977c53debe8b25ad92d0" title="chore(deps): upgrade eslint, prettier &amp; related packages">chore(deps): upgrade eslint, prettier &amp; related packages</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/CODE_OF_CONDUCT.md" title="CODE_OF_CONDUCT.md">CODE_OF_CONDUCT.md</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/c8d7f0a782c3fd04d33373efbc3e740b26011c64" title="feat(tools): remove eslint-plugin-prettier for prettier (#42438)
#
#  * feat: remove eslint-plugin-prettier for prettier
#
#  This removes the annoying lint warnings when all that needs to change is
#  formatting
#
#  * fix: use .js lint-staged config to ignore properly
#
#  * fix: lint everything if a lot of files are changed
#
#  It's faster than making lots of individual linter calls
#
#  * chore: apply prettier
#
#  * fix: ignore code in curriculum-file-structure">feat(tools): remove eslint-plugin-prettier for prettier (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/42438/hovercard" data-id="918560002" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/42438" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/42438">#42438</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/c8d7f0a782c3fd04d33373efbc3e740b26011c64" title="feat(tools): remove eslint-plugin-prettier for prettier (#42438)
#
#  * feat: remove eslint-plugin-prettier for prettier
#
#  This removes the annoying lint warnings when all that needs to change is
#  formatting
#
#  * fix: use .js lint-staged config to ignore properly
#
#  * fix: lint everything if a lot of files are changed
#
#  It's faster than making lots of individual linter calls
#
#  * chore: apply prettier
#
#  * fix: ignore code in curriculum-file-structure">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/CONTRIBUTING.md" title="CONTRIBUTING.md">CONTRIBUTING.md</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/c8d7f0a782c3fd04d33373efbc3e740b26011c64" title="feat(tools): remove eslint-plugin-prettier for prettier (#42438)
#
#  * feat: remove eslint-plugin-prettier for prettier
#
#  This removes the annoying lint warnings when all that needs to change is
#  formatting
#
#  * fix: use .js lint-staged config to ignore properly
#
#  * fix: lint everything if a lot of files are changed
#
#  It's faster than making lots of individual linter calls
#
#  * chore: apply prettier
#
#  * fix: ignore code in curriculum-file-structure">feat(tools): remove eslint-plugin-prettier for prettier (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/42438/hovercard" data-id="918560002" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/42438" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/42438">#42438</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/c8d7f0a782c3fd04d33373efbc3e740b26011c64" title="feat(tools): remove eslint-plugin-prettier for prettier (#42438)
#
#  * feat: remove eslint-plugin-prettier for prettier
#
# ...
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/ae258ce94cee0f13fac18eed845e58255f469818" title="chore: remove removed contributors/tools path (#44374)">chore: remove removed contributors/tools path (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44374/hovercard" data-id="1070706525" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44374" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44374">#44374</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/ae258ce94cee0f13fac18eed845e58255f469818" title="chore: remove removed contributors/tools path (#44374)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/sample.env" title="sample.env">sample.env</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/dd2ff1683c1f31d0aaabf91a78c3d6bef92a6787" title="feat: add curriculum feature flag (#44441)">feat: add curriculum feature flag (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44441/hovercard" data-id="1075801786" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44441" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44441">#44441</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/dd2ff1683c1f31d0aaabf91a78c3d6bef92a6787" title="feat: add curriculum feature flag (#44441)">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/server.Dockerfile" title="server.Dockerfile">server.Dockerfile</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/9c078ab5d2716ced030676f718dffbf59e1a99d3" title="fix: update npm calls to handle workspaces (#44370)
#
#  * fix: use workspaces for crowdin npm ci
#
#  * fix: update server.Dockerfile to use workspaces
#
#  * fix: update client.Dockerfile to use workspaces">fix: update npm calls to handle workspaces (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44370/hovercard" data-id="1070640295" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44370" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44370">#44370</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/9c078ab5d2716ced030676f718dffbf59e1a99d3" title="fix: update npm calls to handle workspaces (#44370)
#
#  * fix: use workspaces for crowdin npm ci
#
#  * fix: update server.Dockerfile to use workspaces
#
#  * fix: update client.Dockerfile to use workspaces">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/tsconfig-base.json" title="tsconfig-base.json">tsconfig-base.json</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">refactor: organise TypeScript config and migrate helpers (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44747/hovercard" data-id="1099061205" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44747" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44747">#44747</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">)</a>
#  </span>,
#  <span class="css-truncate css-truncate-target d-block width-fit"><a class="js-navigation-open Link--primary" data-pjax="#repo-content-pjax-container" href="/freeCodeCamp/freeCodeCamp/blob/main/tsconfig.json" title="tsconfig.json">tsconfig.json</a></span>,
#  <span class="css-truncate css-truncate-target d-block width-fit markdown-title">
#  <a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">refactor: organise TypeScript config and migrate helpers (</a><a class="issue-link js-issue-link" data-error-text="Failed to load title" data-hovercard-type="pull_request" data-hovercard-url="/freeCodeCamp/freeCodeCamp/pull/44747/hovercard" data-id="1099061205" data-permission-text="Title is private" data-url="https://github.com/freeCodeCamp/freeCodeCamp/issues/44747" href="https://github.com/freeCodeCamp/freeCodeCamp/pull/44747">#44747</a><a class="Link--secondary" data-pjax="true" href="/freeCodeCamp/freeCodeCamp/commit/7216ca55cc4fd282ab7fb6615196d82c28df8dc3" title="refactor: organise TypeScript config and migrate helpers (#44747)
#
#  * feat: allow more 1000 steps to be created at once
#
#  * refactor: start migrating to typescript
#
#  * refactor: delete-step to ts
#
#  * refactor: migrated some helpers
#
#  * refactor: migrate create-empty-steps
#
#  * refactor: migrate create-step-between
#
#  * refactor: finish migrating to TS
#
#  * refactor: migrate tests
#
#  * fix: ensure mock.restore is done after each test
#
#  * fix: prevent double-tscing
#
#  * fix: repair the tests
#
#  * chore: use ts-node for scripts
#
#  We don't need the performance boost of incremental compilation and
#  ts-node is easier to work with
#
#  * refactor: consolidate tsconfigs
#
#  * refactor: replace gulp
#
#  * fix: use ts-node for build-curriculum
#
#  * fix: allow ts compilation of config
#
#  * feat: create and use create:config script
#
#  * fix: add /config to eslint projects
#
#  * fix: remove gulp script">)</a>
#  </span>,
#  <span class="flex-auto min-width-0 css-truncate css-truncate-target width-fit">
#  <a class="text-bold" href="https://contribute.freecodecamp.org" rel="noopener noreferrer" role="link" target="_blank" title="https://contribute.freecodecamp.org">contribute.freecodecamp.org</a>
#  </span>,
#  <span class="mr-2 d-flex flex-items-center flex-justify-center" style="min-width:32px;height:32px;">
#  <img alt="patreon" class="octicon rounded-1 d-block" height="32" src="https://github.githubassets.com/images/modules/site/icons/funding_platforms/patreon.svg" width="32"/>
#  </span>,
#  <span class="flex-self-center flex-auto min-width-0 css-truncate css-truncate-target width-fit">
#  <a data-ga-click="Dashboard, click, Nav menu - item:org-profile context:organization" data-hydro-click='{"event_type":"sponsors.repo_funding_links_link_click","payload":{"platform":{"platform_type":"PATREON","platform_url":"https://patreon.com/freecodecamp"},"platforms":[{"platform_type":"GITHUB","platform_url":"https://github.com/freeCodeCamp"},{"platform_type":"PATREON","platform_url":"https://patreon.com/freecodecamp"},{"platform_type":"CUSTOM","platform_url":"www.freecodecamp.org/donate"}],"repo_id":28457823,"owner_id":9892522,"user_id":null,"originating_url":"https://github.com/freeCodeCamp/freeCodeCamp"}}' data-hydro-click-hmac="3fd39d1863d92215cfee81a39e7fc7728ba72a56b7063b892ea3a504a1e28cb7" href="https://patreon.com/freecodecamp" target="_blank"><span>patreon.com/<strong>freecodecamp</strong></span></a>
#  </span>,
#  <span>patreon.com/<strong>freecodecamp</strong></span>,
#  <span class="mr-2 d-flex flex-items-center flex-justify-center" style="min-width:32px;height:32px;">
#  <svg alt="custom" aria-hidden="true" class="octicon octicon-link color-fg-muted" height="16" version="1.1" viewbox="0 0 16 16" width="16"><path d="M7.775 3.275a.75.75 0 001.06 1.06l1.25-1.25a2 2 0 112.83 2.83l-2.5 2.5a2 2 0 01-2.83 0 .75.75 0 00-1.06 1.06 3.5 3.5 0 004.95 0l2.5-2.5a3.5 3.5 0 00-4.95-4.95l-1.25 1.25zm-4.69 9.64a2 2 0 010-2.83l2.5-2.5a2 2 0 012.83 0 .75.75 0 001.06-1.06 3.5 3.5 0 00-4.95 0l-2.5 2.5a3.5 3.5 0 004.95 4.95l1.25-1.25a.75.75 0 00-1.06-1.06l-1.25 1.25a2 2 0 01-2.83 0z" fill-rule="evenodd"></path></svg>
#  </span>,
#  <span class="flex-self-center flex-auto min-width-0 css-truncate css-truncate-target width-fit">
#  <a data-ga-click="Dashboard, click, Nav menu - item:org-profile context:organization" data-hydro-click='{"event_type":"sponsors.repo_funding_links_link_click","payload":{"platform":{"platform_type":"CUSTOM","platform_url":"www.freecodecamp.org/donate"},"platforms":[{"platform_type":"GITHUB","platform_url":"https://github.com/freeCodeCamp"},{"platform_type":"PATREON","platform_url":"https://patreon.com/freecodecamp"},{"platform_type":"CUSTOM","platform_url":"www.freecodecamp.org/donate"}],"repo_id":28457823,"owner_id":9892522,"user_id":null,"originating_url":"https://github.com/freeCodeCamp/freeCodeCamp"}}' data-hydro-click-hmac="d7c749d4930eca97c247b0fdc1d8f081bd9523583637dfa74b200779206e7343" href="http://www.freecodecamp.org/donate" rel="noopener noreferrer" target="_blank">www.freecodecamp.org/donate</a>
#  </span>,
#  <span class="Counter" data-view-component="true" title="1">1</span>,
#  <span class="text-bold color-fg-default">Huh</span>,
#  <span class="Counter" data-view-component="true" title="4,389">4,389</span>,
#  <span class="Progress" data-view-component="true">
#  <span aria-label="JavaScript 47.7" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#f1e05a !important;;width: 47.7%;"></span>
#  <span aria-label="TypeScript 45.9" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#2b7489 !important;;width: 45.9%;"></span>
#  <span aria-label="CSS 6.0" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#563d7c !important;;width: 6.0%;"></span>
#  <span aria-label="Shell 0.2" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#89e051 !important;;width: 0.2%;"></span>
#  <span aria-label="EJS 0.1" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#a91e50 !important;;width: 0.1%;"></span>
#  <span aria-label="Dockerfile 0.1" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#384d54 !important;;width: 0.1%;"></span>
#  </span>,
#  <span aria-label="JavaScript 47.7" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#f1e05a !important;;width: 47.7%;"></span>,
#  <span aria-label="TypeScript 45.9" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#2b7489 !important;;width: 45.9%;"></span>,
#  <span aria-label="CSS 6.0" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#563d7c !important;;width: 6.0%;"></span>,
#  <span aria-label="Shell 0.2" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#89e051 !important;;width: 0.2%;"></span>,
#  <span aria-label="EJS 0.1" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#a91e50 !important;;width: 0.1%;"></span>,
#  <span aria-label="Dockerfile 0.1" class="Progress-item color-bg-success-emphasis" data-view-component="true" itemprop="keywords" style="background-color:#384d54 !important;;width: 0.1%;"></span>,
#  <span class="color-fg-default text-bold mr-1">JavaScript</span>,
#  <span>47.7%</span>,
#  <span class="color-fg-default text-bold mr-1">TypeScript</span>,
#  <span>45.9%</span>,
#  <span class="color-fg-default text-bold mr-1">CSS</span>,
#  <span>6.0%</span>,
#  <span class="color-fg-default text-bold mr-1">Shell</span>,
#  <span>0.2%</span>,
#  <span class="color-fg-default text-bold mr-1">EJS</span>,
#  <span>0.1%</span>,
#  <span class="color-fg-default text-bold mr-1">Dockerfile</span>,
#  <span>0.1%</span>,
#  <span>
#          © 2022 GitHub, Inc.
#          </span>,
#  <span class="f6 color-fg-muted"></span>,
#  <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>,
#  <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>]
