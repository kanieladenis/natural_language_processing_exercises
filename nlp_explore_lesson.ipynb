# %% [markdown]
# # NLP EDA
#
# Basically, exploration and modeling boil down to a single question:
#
# How do we quantify our data/text
#
# In this lesson, we'll explore answers to this question that will aid in visualization.
#
# - word frequency (by label)
# - ngrams
# - word cloud
# - sentiment analysis
# - other common features

# %% [markdown]
# ## Setup
#
# Data is spam/ham text messages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import nltk
import unicodedata
import re

# %%
plt.rc('figure', figsize=(13, 7))
plt.style.use('seaborn-darkgrid')

# %%
def clean(text):
    '''Simplified text cleaning function'''
    text = text.lower()
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return re.sub(r"[^a-z0-9\s]", '', text)

# %%
df = pd.read_csv('spam_clean.csv')
df.head()
# Out:
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#acquire data from spam_db

# from env import user, password, host

# def get_db_url(database, host=host, user=user, password=password):
#     return f'mysql+pymysql://{user}:{password}@{host}/{database}'


# url = get_db_url("spam_db")
# sql = "SELECT * FROM spam"

# df = pd.read_sql(sql, url, index_col="id")
# df.head()

# %%
# pd.set_option('display.max_colwidth', -1)

# %%
# how many spam and ham observations do we have?

df.label.value_counts(normalize = True)
# Out:
# ham     0.865937
# spam    0.134063
# Name: label, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   5572 non-null   object
#  1   text    5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
# combine all messages in single string by label

ham_words = clean(' '.join(df[df.label == 'ham'].text))
ham_words
# Out:
# 'go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat ok lar joking wif u oni u dun say so early hor u c already then say nah i dont think he goes to usf he lives around here though even my brother is not like to speak with me they treat me like aids patent as per your request melle melle oru minnaminunginte nurungu vettam has been set as your callertune for all callers press 9 to copy your friends callertune im gonna be home soon and i dont want to talk about this stuff anymore tonight k ive cried enough today ive been searching for the right words to thank you for this breather i promise i wont take your help for granted and will fulfil my promise you have been wonderful and a blessing at all times i have a date on sunday with will oh kim watching here eh u remember how 2 spell his name yes i did he v naughty make until i v wet fine if thataos the way u feel thataos the way its gota b is that seriously how you spell his name ium going to try for 2 months ha ha only joking so i pay first lar then when is da stock comin aft i finish my lunch then i go str down lor ard 3 smth lor u finish ur lunch already ffffffffff alright no way i can meet up with you sooner just forced myself to eat a slice im really not hungry tho this sucks mark is getting worried he knows im sick when i turn down pizza lol lol your always so convincing did you catch the bus  are you frying an egg  did you make a tea are you eating your moms left over dinner  do you feel my love  im back amp were packing the car now ill let you know if theres room ahhh work i vaguely remember that what does it feel like lol wait thats still not all that clear were you not sure about me being sarcastic or that thats why x doesnt want to live with us yeah he got in at 2 and was v apologetic n had fallen out and she was actin like spoilt child and he got caught up in that till 2 but we wont go there not doing too badly cheers you  k tell me anything about you for fear of fainting with the of all that housework you just did quick have a cuppa yup ok i go home look at the timings then i msg i again xuhui going to learn on 2nd may too but her lesson is at 8am oops ill let you know when my roommates done i see the letter b on my car anything lor u decide hello hows you and how did saturday go i was just texting to see if youd decided to do anything tomo not that im trying to invite myself or anything pls go ahead with watts i just wanted to be sure do have a great weekend abiola did i forget to tell you  i want you  i need you i crave you  but most of all  i love you my sweet arabian steed  mmmmmm  yummy who are you seeing great i hope you like your man well endowed i am  ltgt  inches no callsmessagesmissed calls didnt you get hep b immunisation in nigeria fair enough anything going on yeah hopefully if tyler cant do it i could maybe ask around a bit u dont know how stubborn i am i didnt even want to go to the hospital i kept telling mark im not a weak sucker hospitals are for weak suckers what you thinked about me first time you saw me in class a gram usually runs like  ltgt  a half eighth is smarter though and gets you almost a whole second gram for  ltgt k fyi x has a ride early tomorrow morning but hes crashing at our place tonight wow i never realized that you were so embarassed by your accomodations i thought you liked it since i was doing the best i could and you always seemed so happy about the cave im sorry i didnt and dont have more to give im sorry i offered im sorry your room was so embarassing do you know what mallika sherawat did yesterday find out now   lturlgt sorry ill call later in meeting tell where you reached yesgauti and sehwag out of odi series your gonna have to pick up a 1 burger for yourself on your way home i cant even move pain is killing me ha ha ha good joke girls are situation seekers its a part of checking iq sorry my roommates took forever it ok if i come by now ok lar i double check wif da hair dr ...

# %%
spam_words = clean(' '.join(df[df.label == 'spam'].text))
spam_words
# Out:
# 'free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005 text fa to 87121 to receive entry questionstd txt ratetcs apply 08452810075over18s freemsg hey there darling its been 3 weeks now and no word back id like some fun you up for it still tb ok xxx std chgs to send a150 to rcv winner as a valued network customer you have been selected to receivea a900 prize reward to claim call 09061701461 claim code kl341 valid 12 hours only had your mobile 11 months or more u r entitled to update to the latest colour mobiles with camera for free call the mobile update co free on 08002986030 six chances to win cash from 100 to 20000 pounds txt csh11 and send to 87575 cost 150pday 6days 16 tsandcs apply reply hl 4 info urgent you have won a 1 week free membership in our a100000 prize jackpot txt the word claim to no 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18 xxxmobilemovieclub to use your credit click the wap link in the next txt message or click here httpwap xxxmobilemovieclubcomnqjkgighjjgcbl england v macedonia  dont miss the goalsteam news txt ur national team to 87077 eg england to 87077 trywales scotland 4txti14120 poboxox36504w45wq 16 thanks for your subscription to ringtone uk your mobile will be charged a5month please confirm by replying yes or no if you reply no you will not be charged 07732584351  rodger burns  msg  we tried to call you re your reply to our sms for a free nokia mobile  free camcorder please call now 08000930705 for delivery tomorrow sms ac sptv the new jersey devils and the detroit red wings play ice hockey correct or incorrect end reply end sptv congrats 1 year special cinema pass for 2 is yours call 09061209465 now c suprman v matrix3 starwars3 etc all 4 free bx420ip45we 150pm dont miss out  as a valued customer i am pleased to advise you that following recent review of your mob no you are awarded with a a1500 bonus prize call 09066364589 urgent ur awarded a complimentary trip to eurodisinc trav acoentry41 or a1000 to claim txt dis to 87121 186a150morefrmmob shracomorsglsuplt10 ls1 3aj did you hear about the new divorce barbie it comes with all of kens stuff please call our customer service representative on 0800 169 6031 between 10am9pm as you have won a guaranteed a1000 cash or a5000 prize your free ringtone is waiting to be collected simply text the password mix to 85069 to verify get usher and britney fml gent we are trying to contact you last weekends draw shows that you won a a1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs only 150ppm you are a winner u have been specially selected 2 receive a1000 or a 4 holiday flights inc speak to a live operator 2 claim 0871277810910pmin 18  private your 2004 account statement for 07742676969 shows 786 unredeemed bonus points to claim call 08719180248 identifier code 45239 expires urgent your mobile no was awarded a2000 bonus caller prize on 5903 this is our final try to contact u call from landline 09064019788 box42wr29c 150ppm todays voda numbers ending 7548 are selected to receive a 350 award if you have a match please call 08712300220 quoting claim code 4041 standard rates app sunshine quiz wkly q win a top sony dvd player if u know which country the algarve is in txt ansr to 82277 a150 sptyrone want 2 get laid tonight want real dogging locations sent direct 2 ur mob join the uks largest dogging network bt txting gravel to 69888 nt ec2a 31pmsg150p youll not rcv any more msgs from the chat svc for free hardcore services text go to 69988 if u get nothing u must age verify with yr network  try again freemsg why havent you replied to my text im randy sexy female and live local luv to hear from u netcollex ltd 08700621170150p per msg reply stop to end customer service annoncement you have a new years delivery waiting for you please call 07046744435 now to arrange delivery you are a winner u have been specially selected 2 receive a1000 cash or a 4 holiday flights inc speak to a live operator 2 claim 0871277810810 pls stop bootydelious 3 ...

# %%
all_words = clean(' '.join(df.text))
all_words
# Out:
# 'go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat ok lar joking wif u oni free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005 text fa to 87121 to receive entry questionstd txt ratetcs apply 08452810075over18s u dun say so early hor u c already then say nah i dont think he goes to usf he lives around here though freemsg hey there darling its been 3 weeks now and no word back id like some fun you up for it still tb ok xxx std chgs to send a150 to rcv even my brother is not like to speak with me they treat me like aids patent as per your request melle melle oru minnaminunginte nurungu vettam has been set as your callertune for all callers press 9 to copy your friends callertune winner as a valued network customer you have been selected to receivea a900 prize reward to claim call 09061701461 claim code kl341 valid 12 hours only had your mobile 11 months or more u r entitled to update to the latest colour mobiles with camera for free call the mobile update co free on 08002986030 im gonna be home soon and i dont want to talk about this stuff anymore tonight k ive cried enough today six chances to win cash from 100 to 20000 pounds txt csh11 and send to 87575 cost 150pday 6days 16 tsandcs apply reply hl 4 info urgent you have won a 1 week free membership in our a100000 prize jackpot txt the word claim to no 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18 ive been searching for the right words to thank you for this breather i promise i wont take your help for granted and will fulfil my promise you have been wonderful and a blessing at all times i have a date on sunday with will xxxmobilemovieclub to use your credit click the wap link in the next txt message or click here httpwap xxxmobilemovieclubcomnqjkgighjjgcbl oh kim watching here eh u remember how 2 spell his name yes i did he v naughty make until i v wet fine if thataos the way u feel thataos the way its gota b england v macedonia  dont miss the goalsteam news txt ur national team to 87077 eg england to 87077 trywales scotland 4txti14120 poboxox36504w45wq 16 is that seriously how you spell his name ium going to try for 2 months ha ha only joking so i pay first lar then when is da stock comin aft i finish my lunch then i go str down lor ard 3 smth lor u finish ur lunch already ffffffffff alright no way i can meet up with you sooner just forced myself to eat a slice im really not hungry tho this sucks mark is getting worried he knows im sick when i turn down pizza lol lol your always so convincing did you catch the bus  are you frying an egg  did you make a tea are you eating your moms left over dinner  do you feel my love  im back amp were packing the car now ill let you know if theres room ahhh work i vaguely remember that what does it feel like lol wait thats still not all that clear were you not sure about me being sarcastic or that thats why x doesnt want to live with us yeah he got in at 2 and was v apologetic n had fallen out and she was actin like spoilt child and he got caught up in that till 2 but we wont go there not doing too badly cheers you  k tell me anything about you for fear of fainting with the of all that housework you just did quick have a cuppa thanks for your subscription to ringtone uk your mobile will be charged a5month please confirm by replying yes or no if you reply no you will not be charged yup ok i go home look at the timings then i msg i again xuhui going to learn on 2nd may too but her lesson is at 8am oops ill let you know when my roommates done i see the letter b on my car anything lor u decide hello hows you and how did saturday go i was just texting to see if youd decided to do anything tomo not that im trying to invite myself or anything pls go ahead with watts i just wanted to be sure do have a great weekend abiola did i forget to tell you  i want you  i need you i crave you  but most of all  i love you my sweet arabian steed  mmmmmm  yummy 07732584351  rodger burns  msg  we ...

# %% [markdown]
# ## Exploration
#
# Represent text as word frequencies.

# %%
ham_freq = pd.Series(ham_words.split()).value_counts()
spam_freq = pd.Series(spam_words.split()).value_counts()
all_freq = pd.Series(all_words.split()).value_counts()

# %%
ham_freq
# Out:
# i                2305
# you              1837
# to               1554
# the              1118
# a                1055
#                  ...
# sensesrespect       1
# terminatedwe        1
# mths                1
# poortiyagi          1
# yalru               1
# Length: 7555, dtype: int64

# %%
# concat all frequencies together into a dataframe

word_counts = pd.concat([ham_freq, spam_freq, all_freq], axis=1).fillna(0).astype(int)
word_counts.columns = ['ham', 'spam', 'all']
word_counts.head()
# Out:
#       ham  spam   all
# i    2305    45  2350
# you  1837   287  2124
# to   1554   686  2240
# the  1118   204  1322
# a    1055   376  1431

# %% [markdown]
# - What are the most frequently occuring words?
# - Are there any words that uniquely identify a spam or ham message? I.e. words present in one type of message but not the other?

# %%
# sort by 'all'

word_counts.sort_values('all', ascending=False).head(20)
# Out:
#        ham  spam   all
# i     2305    45  2350
# to    1554   686  2240
# you   1837   287  2124
# a     1055   376  1431
# the   1118   204  1322
# u      986   147  1133
# and    848   122   970
# is     728   158   886
# in     811    73   884
# me     756    30   786
# my     743    10   753
# for    501   203   704
# your   414   263   677
# of     524    95   619
# it     590    28   618
# call   229   347   576
# have   438   135   573
# on     391   144   535
# that   486    26   512
# are    409    80   489

# %%
# sort by 'ham' and 'spam' columns
word_counts.sort_values(['ham', 'spam'], ascending=[True, False]).head(20)
# Out:
#             ham  spam  all
# claim         0   113  113
# prize         0    92   92
# won           0    73   73
# guaranteed    0    50   50
# tone          0    48   48
# 18            0    43   43
# awarded       0    38   38
# a1000         0    35   35
# 150ppm        0    34   34
# a2000         0    31   31
# tcs           0    29   29
# a150          0    27   27
# collection    0    26   26
# ringtone      0    26   26
# entry         0    26   26
# tones         0    25   25
# 500           0    25   25
# weekly        0    24   24
# mob           0    24   24
# 150p          0    23   23

# %% [markdown]
# ### Visualization
#
# - ham vs spam count for 20 most common words
# - ham vs spam proportion for 20 most common words

# %%
plt.rc('font', size=18)
word_counts.sort_values('all', ascending=False).head(20)[['spam', 'ham']].plot.barh()
plt.title('Ham vs Spam count for the top 20 most frequent words')
# Out:
# Text(0.5, 1.0, 'Ham vs Spam count for the top 20 most frequent words')

# %%
plt.figure(figsize=(16, 9))
plt.rc('font', size=16)

(word_counts.sort_values('all', ascending=False)
 .head(20)
 .apply(lambda row: row/row['all'], axis = 1)
 .drop(columns = 'all')
 .sort_values(by = 'spam')
 .plot.barh(stacked = True, width = 1, ec = 'k')
)
plt.title('% of spam vs ham for the most common 20 words')
# Out:
# Text(0.5, 1.0, '% of spam vs ham for the most common 20 words')

# %% [markdown]
# ## n-grams
#
# **bigram**: combinations of 2 words
#
# Represent text as combinations of 2 words

# %%
sentence = 'Today is tuesday, and the weather is nice.'

# %%
list(nltk.bigrams(sentence.split()))
# Out:
# [('Today', 'is'),
#  ('is', 'tuesday,'),
#  ('tuesday,', 'and'),
#  ('and', 'the'),
#  ('the', 'weather'),
#  ('weather', 'is'),
#  ('is', 'nice.')]

# %% [markdown]
# **Be Careful!** Make sure you are making bigrams out of *words*.

# %%
# Don't do this!
# list(nltk.bigrams(sentence))

# %% [markdown]
# - what are the most common bigrams? spam bigrams? ham bigrams?
# - visualize 20 most common bigrams, most common ham bigrams
# - ngrams
#
# Find the most common bigram and then find a representative text

# %%
pd.Series(nltk.bigrams(spam_words.split())).value_counts().head(10).plot.barh()
plt.title('Top 10 most common spam bigrams')
# Out:
# Text(0.5, 1.0, 'Top 10 most common spam bigrams')

# %%
spam_words.split()
# Out:
# ['free',
#  'entry',
#  'in',
#  '2',
#  'a',
#  'wkly',
#  'comp',
#  'to',
#  'win',
#  'fa',
#  'cup',
#  'final',
#  'tkts',
#  '21st',
#  'may',
#  '2005',
#  'text',
#  'fa',
#  'to',
#  '87121',
#  'to',
#  'receive',
#  'entry',
#  'questionstd',
#  'txt',
#  'ratetcs',
#  'apply',
#  '08452810075over18s',
#  'freemsg',
#  'hey',
#  'there',
#  'darling',
#  'its',
#  'been',
#  '3',
#  'weeks',
#  'now',
#  'and',
#  'no',
#  'word',
#  'back',
#  'id',
#  'like',
#  'some',
#  'fun',
#  'you',
#  'up',
#  'for',
#  'it',
#  'still',
#  'tb',
#  'ok',
#  'xxx',
#  'std',
#  'chgs',
#  'to',
#  'send',
#  'a150',
#  'to',
#  'rcv',
#  'winner',
#  'as',
#  'a',
#  'valued',
#  'network',
#  'customer',
#  'you',
#  'have',
#  'been',
#  'selected',
#  'to',
#  'receivea',
#  'a900',
#  'prize',
#  'reward',
#  'to',
#  'claim',
#  'call',
#  '09061701461',
#  'claim',
#  'code',
#  'kl341',
#  'valid',
#  '12',
#  'hours',
#  'only',
#  'had',
#  'your',
#  'mobile',
#  '11',
#  'months',
#  'or',
#  'more',
#  'u',
#  'r',
#  'entitled',
#  'to',
#  'update',
#  'to',
#  'the',
#  'latest',
#  'colour',
#  'mobiles',
#  'with',
#  'camera',
#  'for',
#  'free',
#  'call',
#  'the',
#  'mobile',
#  'update',
#  'co',
#  'free',
#  'on',
#  '08002986030',
#  'six',
#  'chances',
#  'to',
#  'win',
#  'cash',
#  'from',
#  '100',
#  'to',
#  '20000',
#  'pounds',
#  'txt',
#  'csh11',
#  'and',
#  'send',
#  'to',
#  '87575',
#  'cost',
#  '150pday',
#  '6days',
#  '16',
#  'tsandcs',
#  'apply',
#  'reply',
#  'hl',
#  '4',
#  'info',
#  'urgent',
#  'you',
#  'have',
#  'won',
#  'a',
#  '1',
#  'week',
#  'free',
#  'membership',
#  'in',
#  'our',
#  'a100000',
#  'prize',
#  'jackpot',
#  'txt',
#  'the',
#  'word',
#  'claim',
#  'to',
#  'no',
#  '81010',
#  'tc',
#  'wwwdbuknet',
#  'lccltd',
#  'pobox',
#  '4403ldnw1a7rw18',
#  'xxxmobilemovieclub',
#  'to',
#  'use',
#  'your',
#  'credit',
#  'click',
#  'the',
#  'wap',
#  'link',
#  'in',
#  'the',
#  'next',
#  'txt',
#  'message',
#  'or',
#  'click',
#  'here',
#  'httpwap',
#  'xxxmobilemovieclubcomnqjkgighjjgcbl',
#  'england',
#  'v',
#  'macedonia',
#  'dont',
#  'miss',
#  'the',
#  'goalsteam',
#  'news',
#  'txt',
#  'ur',
#  'national',
#  'team',
#  'to',
#  '87077',
#  'eg',
#  'england',
#  'to',
#  '87077',
#  'trywales',
#  'scotland',
#  '4txti14120',
#  'poboxox36504w45wq',
#  '16',
#  'thanks',
#  'for',
#  'your',
#  'subscription',
#  'to',
#  'ringtone',
#  'uk',
#  'your',
#  'mobile',
#  'will',
#  'be',
#  'charged',
#  'a5month',
#  'please',
#  'confirm',
#  'by',
#  'replying',
#  'yes',
#  'or',
#  'no',
#  'if',
#  'you',
#  'reply',
#  'no',
#  'you',
#  'will',
#  'not',
#  'be',
#  'charged',
#  '07732584351',
#  'rodger',
#  'burns',
#  'msg',
#  'we',
#  'tried',
#  'to',
#  'call',
#  'you',
#  're',
#  'your',
#  'reply',
#  'to',
#  'our',
#  'sms',
#  'for',
#  'a',
#  'free',
#  'nokia',
#  'mobile',
#  'free',
#  'camcorder',
#  'please',
#  'call',
#  'now',
#  '08000930705',
#  'for',
#  'delivery',
#  'tomorrow',
#  'sms',
#  'ac',
#  'sptv',
#  'the',
#  'new',
#  'jersey',
#  'devils',
#  'and',
#  'the',
#  'detroit',
#  'red',
#  'wings',
#  'play',
#  'ice',
#  'hockey',
#  'correct',
#  'or',
#  'incorrect',
#  'end',
#  'reply',
#  'end',
#  'sptv',
#  'congrats',
#  '1',
#  'year',
#  'special',
#  'cinema',
#  'pass',
#  'for',
#  '2',
#  'is',
#  'yours',
#  'call',
#  '09061209465',
#  'now',
#  'c',
#  'suprman',
#  'v',
#  'matrix3',
#  'starwars3',
#  'etc',
#  'all',
#  '4',
#  'free',
#  'bx420ip45we',
#  '150pm',
#  'dont',
#  'miss',
#  'out',
#  'as',
#  'a',
#  'valued',
#  'customer',
#  'i',
#  'am',
#  'pleased',
#  'to',
#  'advise',
#  'you',
#  'that',
#  'following',
#  'recent',
#  'review',
#  'of',
#  'your',
#  'mob',
#  'no',
#  'you',
#  'are',
#  'awarded',
#  'with',
#  'a',
#  'a1500',
#  'bonus',
#  'prize',
#  'call',
#  '09066364589',
#  'urgent',
#  'ur',
#  'awarded',
#  'a',
#  'complimentary',
#  'trip',
#  'to',
#  'eurodisinc',
#  'trav',
#  'acoentry41',
#  'or',
#  'a1000',
#  'to',
#  'claim',
#  'txt',
#  'dis',
#  'to',
#  '87121',
#  '186a150morefrmmob',
#  'shracomorsglsuplt10',
#  'ls1',
#  '3aj',
#  'did',
#  'you',
#  'hear',
#  'about',
#  'the',
#  'new',
#  'divorce',
#  'barbie',
#  'it',
#  'comes',
#  'with',
#  'all',
#  'of',
#  'kens',
#  'stuff',
#  'please',
#  'call',
#  'our',
#  'customer',
#  'service',
#  'representative',
#  'on',
#  '0800',
#  '169',
#  '6031',
#  'between',
#  '10am9pm',
#  'as',
#  'you',
#  'have',
#  'won',
#  'a',
#  'guaranteed',
#  'a1000',
#  'cash',
#  'or',
#  'a5000',
#  'prize',
#  'your',
#  'free',
#  'ringtone',
#  'is',
#  'waiting',
#  'to',
#  'be',
#  'collected',
#  'simply',
#  'text',
#  'the',
#  'password',
#  'mix',
#  'to',
#  '85069',
#  'to',
#  'verify',
#  'get',
#  'usher',
#  'and',
#  'britney',
#  'fml',
#  'gent',
#  'we',
#  'are',
#  'trying',
#  'to',
#  'contact',
#  'you',
#  'last',
#  'weekends',
#  'draw',
#  'shows',
#  'that',
#  'you',
#  'won',
#  'a',
#  'a1000',
#  'prize',
#  'guaranteed',
#  'call',
#  '09064012160',
#  'claim',
#  'code',
#  'k52',
#  'valid',
#  '12hrs',
#  'only',
#  '150ppm',
#  'you',
#  'are',
#  'a',
#  'winner',
#  'u',
#  'have',
#  'been',
#  'specially',
#  'selected',
#  '2',
#  'receive',
#  'a1000',
#  'or',
#  'a',
#  '4',
#  'holiday',
#  'flights',
#  'inc',
#  'speak',
#  'to',
#  'a',
#  'live',
#  'operator',
#  '2',
#  'claim',
#  '0871277810910pmin',
#  '18',
#  'private',
#  'your',
#  '2004',
#  'account',
#  'statement',
#  'for',
#  '07742676969',
#  'shows',
#  '786',
#  'unredeemed',
#  'bonus',
#  'points',
#  'to',
#  'claim',
#  'call',
#  '08719180248',
#  'identifier',
#  'code',
#  '45239',
#  'expires',
#  'urgent',
#  'your',
#  'mobile',
#  'no',
#  'was',
#  'awarded',
#  'a2000',
#  'bonus',
#  'caller',
#  'prize',
#  'on',
#  '5903',
#  'this',
#  'is',
#  'our',
#  'final',
#  'try',
#  'to',
#  'contact',
#  'u',
#  'call',
#  'from',
#  'landline',
#  '09064019788',
#  'box42wr29c',
#  '150ppm',
#  'todays',
#  'voda',
#  'numbers',
#  'ending',
#  '7548',
#  'are',
#  'selected',
#  'to',
#  'receive',
#  'a',
#  '350',
#  'award',
#  'if',
#  'you',
#  'have',
#  'a',
#  'match',
#  'please',
#  'call',
#  '08712300220',
#  'quoting',
#  'claim',
#  'code',
#  '4041',
#  'standard',
#  'rates',
#  'app',
#  'sunshine',
#  'quiz',
#  'wkly',
#  'q',
#  'win',
#  'a',
#  'top',
#  'sony',
#  'dvd',
#  'player',
#  'if',
#  'u',
#  'know',
#  'which',
#  'country',
#  'the',
#  'algarve',
#  'is',
#  'in',
#  'txt',
#  'ansr',
#  'to',
#  '82277',
#  'a150',
#  'sptyrone',
#  'want',
#  '2',
#  'get',
#  'laid',
#  'tonight',
#  'want',
#  'real',
#  'dogging',
#  'locations',
#  'sent',
#  'direct',
#  '2',
#  'ur',
#  'mob',
#  'join',
#  'the',
#  'uks',
#  'largest',
#  'dogging',
#  'network',
#  'bt',
#  'txting',
#  'gravel',
#  'to',
#  '69888',
#  'nt',
#  'ec2a',
#  '31pmsg150p',
#  'youll',
#  'not',
#  'rcv',
#  'any',
#  'more',
#  'msgs',
#  'from',
#  'the',
#  'chat',
#  'svc',
#  'for',
#  'free',
#  'hardcore',
#  'services',
#  'text',
#  'go',
#  'to',
#  '69988',
#  'if',
#  'u',
#  'get',
#  'nothing',
#  'u',
#  'must',
#  'age',
#  'verify',
#  'with',
#  'yr',
#  'network',
#  'try',
#  'again',
#  'freemsg',
#  'why',
#  'havent',
#  'you',
#  'replied',
#  'to',
#  'my',
#  'text',
#  'im',
#  'randy',
#  'sexy',
#  'female',
#  'and',
#  'live',
#  'local',
#  'luv',
#  'to',
#  'hear',
#  'from',
#  'u',
#  'netcollex',
#  'ltd',
#  '08700621170150p',
#  'per',
#  'msg',
#  'reply',
#  'stop',
#  'to',
#  'end',
#  'customer',
#  'service',
#  'annoncement',
#  'you',
#  'have',
#  'a',
#  'new',
#  'years',
#  'delivery',
#  'waiting',
#  'for',
#  'you',
#  'please',
#  'call',
#  '07046744435',
#  'now',
#  'to',
#  'arrange',
#  'delivery',
#  'you',
#  'are',
#  'a',
#  'winner',
#  'u',
#  'have',
#  'been',
#  'specially',
#  'selected',
#  '2',
#  'receive',
#  'a1000',
#  'cash',
#  'or',
#  'a',
#  '4',
#  'holiday',
#  'flights',
#  'inc',
#  'speak',
#  'to',
#  'a',
#  'live',
#  'operator',
#  '2',
#  'claim',
#  '0871277810810',
#  'pls',
#  'stop',
#  'bootydelious',
#  '32f',
#  'is',
#  'inviting',
#  'you',
#  'to',
#  'be',
#  'her',
#  'friend',
#  'reply',
#  'yes434',
#  'or',
#  'no434',
#  'see',
#  'her',
#  'wwwsmsacubootydelious',
#  'stop',
#  'send',
#  'stop',
#  'frnd',
#  'to',
#  '62468',
#  'bangbabes',
#  'ur',
#  'order',
#  'is',
#  'on',
#  'the',
#  'way',
#  'u',
#  'should',
#  'receive',
#  'a',
#  'service',
#  'msg',
#  '2',
#  'download',
#  'ur',
#  'content',
#  'if',
#  'u',
#  'do',
#  'not',
#  'goto',
#  'wap',
#  'bangb',
#  'tv',
#  'on',
#  'ur',
#  'mobile',
#  'internetservice',
#  'menu',
#  'urgent',
#  'we',
#  'are',
#  'trying',
#  'to',
#  'contact',
#  'you',
#  'last',
#  'weekends',
#  'draw',
#  'shows',
#  'that',
#  'you',
#  'have',
#  'won',
#  'a',
#  'a900',
#  'prize',
#  'guaranteed',
#  'call',
#  '09061701939',
#  'claim',
#  'code',
#  's89',
#  'valid',
#  '12hrs',
#  'only',
#  'please',
#  'call',
#  'our',
#  'customer',
#  'service',
#  'representative',
#  'on',
#  'freephone',
#  '0808',
#  '145',
#  '4742',
#  'between',
#  '9am11pm',
#  'as',
#  'you',
#  'have',
#  'won',
#  'a',
#  'guaranteed',
#  'a1000',
#  'cash',
#  'or',
#  'a5000',
#  'prize',
#  'are',
#  'you',
#  'unique',
#  'enough',
#  'find',
#  'out',
#  'from',
#  '30th',
#  'august',
#  'wwwareyouuniquecouk',
#  '500',
#  'new',
#  'mobiles',
#  'from',
#  '2004',
#  'must',
#  'go',
#  'txt',
#  'nokia',
#  'to',
#  'no',
#  '89545',
#  'collect',
#  'yours',
#  'todayfrom',
#  'only',
#  'a1',
#  'www4tcbiz',
#  '2optout',
#  '08718726270150gbpmtmsg18',
#  'will',
#  'u',
#  'meet',
#  'ur',
#  'dream',
#  'partner',
#  'soon',
#  'is',
#  'ur',
#  'career',
#  'off',
#  '2',
#  'a',
#  'flyng',
#  'start',
#  '2',
#  'find',
#  'out',
#  'free',
#  'txt',
#  'horo',
#  'followed',
#  'by',
#  'ur',
#  'star',
#  'sign',
#  'e',
#  'g',
#  'horo',
#  'aries',
#  'text',
#  'meet',
#  'someone',
#  'sexy',
#  'today',
#  'u',
#  'can',
#  'find',
#  'a',
#  'date',
#  'or',
#  'even',
#  'flirt',
#  'its',
#  'up',
#  'to',
#  'u',
#  'join',
#  '4',
#  'just',
#  '10p',
#  'reply',
#  'with',
#  'name',
#  'age',
#  'eg',
#  'sam',
#  '25',
#  '18',
#  'msg',
#  'recdthirtyeight',
#  'pence',
#  'u',
#  '447801259231',
#  'have',
#  'a',
#  'secret',
#  'admirer',
#  'who',
#  'is',
#  'looking',
#  '2',
#  'make',
#  'contact',
#  'with',
#  'ufind',
#  'out',
#  'who',
#  'they',
#  'rreveal',
#  'who',
#  'thinks',
#  'ur',
#  'so',
#  'specialcall',
#  'on',
#  '09058094597',
#  'congratulations',
#  'ur',
#  'awarded',
#  '500',
#  'of',
#  'cd',
#  'vouchers',
#  'or',
#  '125gift',
#  'guaranteed',
#  'free',
#  'entry',
#  '2',
#  '100',
#  'wkly',
#  'draw',
#  'txt',
#  'music',
#  'to',
#  '87066',
#  'tncs',
#  'wwwldewcom1win150ppmx3age16',
#  'we',
#  'tried',
#  'to',
#  'contact',
#  'you',
#  're',
#  'your',
#  'reply',
#  'to',
#  'our',
#  'offer',
#  'of',
#  'a',
#  'video',
#  'handset',
#  '750',
#  'anytime',
#  'networks',
#  'mins',
#  'unlimited',
#  'text',
#  'camcorder',
#  'reply',
#  'or',
#  'call',
#  '08000930705',
#  'now',
#  'hey',
#  'i',
#  'am',
#  'really',
#  'horny',
#  'want',
#  'to',
#  'chat',
#  'or',
#  'see',
#  'me',
#  'naked',
#  'text',
#  'hot',
#  'to',
#  '69698',
#  'text',
#  ...]

# %%
list(nltk.bigrams(spam_words.split()))
# Out:
# [('free', 'entry'),
#  ('entry', 'in'),
#  ('in', '2'),
#  ('2', 'a'),
#  ('a', 'wkly'),
#  ('wkly', 'comp'),
#  ('comp', 'to'),
#  ('to', 'win'),
#  ('win', 'fa'),
#  ('fa', 'cup'),
#  ('cup', 'final'),
#  ('final', 'tkts'),
#  ('tkts', '21st'),
#  ('21st', 'may'),
#  ('may', '2005'),
#  ('2005', 'text'),
#  ('text', 'fa'),
#  ('fa', 'to'),
#  ('to', '87121'),
#  ('87121', 'to'),
#  ('to', 'receive'),
#  ('receive', 'entry'),
#  ('entry', 'questionstd'),
#  ('questionstd', 'txt'),
#  ('txt', 'ratetcs'),
#  ('ratetcs', 'apply'),
#  ('apply', '08452810075over18s'),
#  ('08452810075over18s', 'freemsg'),
#  ('freemsg', 'hey'),
#  ('hey', 'there'),
#  ('there', 'darling'),
#  ('darling', 'its'),
#  ('its', 'been'),
#  ('been', '3'),
#  ('3', 'weeks'),
#  ('weeks', 'now'),
#  ('now', 'and'),
#  ('and', 'no'),
#  ('no', 'word'),
#  ('word', 'back'),
#  ('back', 'id'),
#  ('id', 'like'),
#  ('like', 'some'),
#  ('some', 'fun'),
#  ('fun', 'you'),
#  ('you', 'up'),
#  ('up', 'for'),
#  ('for', 'it'),
#  ('it', 'still'),
#  ('still', 'tb'),
#  ('tb', 'ok'),
#  ('ok', 'xxx'),
#  ('xxx', 'std'),
#  ('std', 'chgs'),
#  ('chgs', 'to'),
#  ('to', 'send'),
#  ('send', 'a150'),
#  ('a150', 'to'),
#  ('to', 'rcv'),
#  ('rcv', 'winner'),
#  ('winner', 'as'),
#  ('as', 'a'),
#  ('a', 'valued'),
#  ('valued', 'network'),
#  ('network', 'customer'),
#  ('customer', 'you'),
#  ('you', 'have'),
#  ('have', 'been'),
#  ('been', 'selected'),
#  ('selected', 'to'),
#  ('to', 'receivea'),
#  ('receivea', 'a900'),
#  ('a900', 'prize'),
#  ('prize', 'reward'),
#  ('reward', 'to'),
#  ('to', 'claim'),
#  ('claim', 'call'),
#  ('call', '09061701461'),
#  ('09061701461', 'claim'),
#  ('claim', 'code'),
#  ('code', 'kl341'),
#  ('kl341', 'valid'),
#  ('valid', '12'),
#  ('12', 'hours'),
#  ('hours', 'only'),
#  ('only', 'had'),
#  ('had', 'your'),
#  ('your', 'mobile'),
#  ('mobile', '11'),
#  ('11', 'months'),
#  ('months', 'or'),
#  ('or', 'more'),
#  ('more', 'u'),
#  ('u', 'r'),
#  ('r', 'entitled'),
#  ('entitled', 'to'),
#  ('to', 'update'),
#  ('update', 'to'),
#  ('to', 'the'),
#  ('the', 'latest'),
#  ('latest', 'colour'),
#  ('colour', 'mobiles'),
#  ('mobiles', 'with'),
#  ('with', 'camera'),
#  ('camera', 'for'),
#  ('for', 'free'),
#  ('free', 'call'),
#  ('call', 'the'),
#  ('the', 'mobile'),
#  ('mobile', 'update'),
#  ('update', 'co'),
#  ('co', 'free'),
#  ('free', 'on'),
#  ('on', '08002986030'),
#  ('08002986030', 'six'),
#  ('six', 'chances'),
#  ('chances', 'to'),
#  ('to', 'win'),
#  ('win', 'cash'),
#  ('cash', 'from'),
#  ('from', '100'),
#  ('100', 'to'),
#  ('to', '20000'),
#  ('20000', 'pounds'),
#  ('pounds', 'txt'),
#  ('txt', 'csh11'),
#  ('csh11', 'and'),
#  ('and', 'send'),
#  ('send', 'to'),
#  ('to', '87575'),
#  ('87575', 'cost'),
#  ('cost', '150pday'),
#  ('150pday', '6days'),
#  ('6days', '16'),
#  ('16', 'tsandcs'),
#  ('tsandcs', 'apply'),
#  ('apply', 'reply'),
#  ('reply', 'hl'),
#  ('hl', '4'),
#  ('4', 'info'),
#  ('info', 'urgent'),
#  ('urgent', 'you'),
#  ('you', 'have'),
#  ('have', 'won'),
#  ('won', 'a'),
#  ('a', '1'),
#  ('1', 'week'),
#  ('week', 'free'),
#  ('free', 'membership'),
#  ('membership', 'in'),
#  ('in', 'our'),
#  ('our', 'a100000'),
#  ('a100000', 'prize'),
#  ('prize', 'jackpot'),
#  ('jackpot', 'txt'),
#  ('txt', 'the'),
#  ('the', 'word'),
#  ('word', 'claim'),
#  ('claim', 'to'),
#  ('to', 'no'),
#  ('no', '81010'),
#  ('81010', 'tc'),
#  ('tc', 'wwwdbuknet'),
#  ('wwwdbuknet', 'lccltd'),
#  ('lccltd', 'pobox'),
#  ('pobox', '4403ldnw1a7rw18'),
#  ('4403ldnw1a7rw18', 'xxxmobilemovieclub'),
#  ('xxxmobilemovieclub', 'to'),
#  ('to', 'use'),
#  ('use', 'your'),
#  ('your', 'credit'),
#  ('credit', 'click'),
#  ('click', 'the'),
#  ('the', 'wap'),
#  ('wap', 'link'),
#  ('link', 'in'),
#  ('in', 'the'),
#  ('the', 'next'),
#  ('next', 'txt'),
#  ('txt', 'message'),
#  ('message', 'or'),
#  ('or', 'click'),
#  ('click', 'here'),
#  ('here', 'httpwap'),
#  ('httpwap', 'xxxmobilemovieclubcomnqjkgighjjgcbl'),
#  ('xxxmobilemovieclubcomnqjkgighjjgcbl', 'england'),
#  ('england', 'v'),
#  ('v', 'macedonia'),
#  ('macedonia', 'dont'),
#  ('dont', 'miss'),
#  ('miss', 'the'),
#  ('the', 'goalsteam'),
#  ('goalsteam', 'news'),
#  ('news', 'txt'),
#  ('txt', 'ur'),
#  ('ur', 'national'),
#  ('national', 'team'),
#  ('team', 'to'),
#  ('to', '87077'),
#  ('87077', 'eg'),
#  ('eg', 'england'),
#  ('england', 'to'),
#  ('to', '87077'),
#  ('87077', 'trywales'),
#  ('trywales', 'scotland'),
#  ('scotland', '4txti14120'),
#  ('4txti14120', 'poboxox36504w45wq'),
#  ('poboxox36504w45wq', '16'),
#  ('16', 'thanks'),
#  ('thanks', 'for'),
#  ('for', 'your'),
#  ('your', 'subscription'),
#  ('subscription', 'to'),
#  ('to', 'ringtone'),
#  ('ringtone', 'uk'),
#  ('uk', 'your'),
#  ('your', 'mobile'),
#  ('mobile', 'will'),
#  ('will', 'be'),
#  ('be', 'charged'),
#  ('charged', 'a5month'),
#  ('a5month', 'please'),
#  ('please', 'confirm'),
#  ('confirm', 'by'),
#  ('by', 'replying'),
#  ('replying', 'yes'),
#  ('yes', 'or'),
#  ('or', 'no'),
#  ('no', 'if'),
#  ('if', 'you'),
#  ('you', 'reply'),
#  ('reply', 'no'),
#  ('no', 'you'),
#  ('you', 'will'),
#  ('will', 'not'),
#  ('not', 'be'),
#  ('be', 'charged'),
#  ('charged', '07732584351'),
#  ('07732584351', 'rodger'),
#  ('rodger', 'burns'),
#  ('burns', 'msg'),
#  ('msg', 'we'),
#  ('we', 'tried'),
#  ('tried', 'to'),
#  ('to', 'call'),
#  ('call', 'you'),
#  ('you', 're'),
#  ('re', 'your'),
#  ('your', 'reply'),
#  ('reply', 'to'),
#  ('to', 'our'),
#  ('our', 'sms'),
#  ('sms', 'for'),
#  ('for', 'a'),
#  ('a', 'free'),
#  ('free', 'nokia'),
#  ('nokia', 'mobile'),
#  ('mobile', 'free'),
#  ('free', 'camcorder'),
#  ('camcorder', 'please'),
#  ('please', 'call'),
#  ('call', 'now'),
#  ('now', '08000930705'),
#  ('08000930705', 'for'),
#  ('for', 'delivery'),
#  ('delivery', 'tomorrow'),
#  ('tomorrow', 'sms'),
#  ('sms', 'ac'),
#  ('ac', 'sptv'),
#  ('sptv', 'the'),
#  ('the', 'new'),
#  ('new', 'jersey'),
#  ('jersey', 'devils'),
#  ('devils', 'and'),
#  ('and', 'the'),
#  ('the', 'detroit'),
#  ('detroit', 'red'),
#  ('red', 'wings'),
#  ('wings', 'play'),
#  ('play', 'ice'),
#  ('ice', 'hockey'),
#  ('hockey', 'correct'),
#  ('correct', 'or'),
#  ('or', 'incorrect'),
#  ('incorrect', 'end'),
#  ('end', 'reply'),
#  ('reply', 'end'),
#  ('end', 'sptv'),
#  ('sptv', 'congrats'),
#  ('congrats', '1'),
#  ('1', 'year'),
#  ('year', 'special'),
#  ('special', 'cinema'),
#  ('cinema', 'pass'),
#  ('pass', 'for'),
#  ('for', '2'),
#  ('2', 'is'),
#  ('is', 'yours'),
#  ('yours', 'call'),
#  ('call', '09061209465'),
#  ('09061209465', 'now'),
#  ('now', 'c'),
#  ('c', 'suprman'),
#  ('suprman', 'v'),
#  ('v', 'matrix3'),
#  ('matrix3', 'starwars3'),
#  ('starwars3', 'etc'),
#  ('etc', 'all'),
#  ('all', '4'),
#  ('4', 'free'),
#  ('free', 'bx420ip45we'),
#  ('bx420ip45we', '150pm'),
#  ('150pm', 'dont'),
#  ('dont', 'miss'),
#  ('miss', 'out'),
#  ('out', 'as'),
#  ('as', 'a'),
#  ('a', 'valued'),
#  ('valued', 'customer'),
#  ('customer', 'i'),
#  ('i', 'am'),
#  ('am', 'pleased'),
#  ('pleased', 'to'),
#  ('to', 'advise'),
#  ('advise', 'you'),
#  ('you', 'that'),
#  ('that', 'following'),
#  ('following', 'recent'),
#  ('recent', 'review'),
#  ('review', 'of'),
#  ('of', 'your'),
#  ('your', 'mob'),
#  ('mob', 'no'),
#  ('no', 'you'),
#  ('you', 'are'),
#  ('are', 'awarded'),
#  ('awarded', 'with'),
#  ('with', 'a'),
#  ('a', 'a1500'),
#  ('a1500', 'bonus'),
#  ('bonus', 'prize'),
#  ('prize', 'call'),
#  ('call', '09066364589'),
#  ('09066364589', 'urgent'),
#  ('urgent', 'ur'),
#  ('ur', 'awarded'),
#  ('awarded', 'a'),
#  ('a', 'complimentary'),
#  ('complimentary', 'trip'),
#  ('trip', 'to'),
#  ('to', 'eurodisinc'),
#  ('eurodisinc', 'trav'),
#  ('trav', 'acoentry41'),
#  ('acoentry41', 'or'),
#  ('or', 'a1000'),
#  ('a1000', 'to'),
#  ('to', 'claim'),
#  ('claim', 'txt'),
#  ('txt', 'dis'),
#  ('dis', 'to'),
#  ('to', '87121'),
#  ('87121', '186a150morefrmmob'),
#  ('186a150morefrmmob', 'shracomorsglsuplt10'),
#  ('shracomorsglsuplt10', 'ls1'),
#  ('ls1', '3aj'),
#  ('3aj', 'did'),
#  ('did', 'you'),
#  ('you', 'hear'),
#  ('hear', 'about'),
#  ('about', 'the'),
#  ('the', 'new'),
#  ('new', 'divorce'),
#  ('divorce', 'barbie'),
#  ('barbie', 'it'),
#  ('it', 'comes'),
#  ('comes', 'with'),
#  ('with', 'all'),
#  ('all', 'of'),
#  ('of', 'kens'),
#  ('kens', 'stuff'),
#  ('stuff', 'please'),
#  ('please', 'call'),
#  ('call', 'our'),
#  ('our', 'customer'),
#  ('customer', 'service'),
#  ('service', 'representative'),
#  ('representative', 'on'),
#  ('on', '0800'),
#  ('0800', '169'),
#  ('169', '6031'),
#  ('6031', 'between'),
#  ('between', '10am9pm'),
#  ('10am9pm', 'as'),
#  ('as', 'you'),
#  ('you', 'have'),
#  ('have', 'won'),
#  ('won', 'a'),
#  ('a', 'guaranteed'),
#  ('guaranteed', 'a1000'),
#  ('a1000', 'cash'),
#  ('cash', 'or'),
#  ('or', 'a5000'),
#  ('a5000', 'prize'),
#  ('prize', 'your'),
#  ('your', 'free'),
#  ('free', 'ringtone'),
#  ('ringtone', 'is'),
#  ('is', 'waiting'),
#  ('waiting', 'to'),
#  ('to', 'be'),
#  ('be', 'collected'),
#  ('collected', 'simply'),
#  ('simply', 'text'),
#  ('text', 'the'),
#  ('the', 'password'),
#  ('password', 'mix'),
#  ('mix', 'to'),
#  ('to', '85069'),
#  ('85069', 'to'),
#  ('to', 'verify'),
#  ('verify', 'get'),
#  ('get', 'usher'),
#  ('usher', 'and'),
#  ('and', 'britney'),
#  ('britney', 'fml'),
#  ('fml', 'gent'),
#  ('gent', 'we'),
#  ('we', 'are'),
#  ('are', 'trying'),
#  ('trying', 'to'),
#  ('to', 'contact'),
#  ('contact', 'you'),
#  ('you', 'last'),
#  ('last', 'weekends'),
#  ('weekends', 'draw'),
#  ('draw', 'shows'),
#  ('shows', 'that'),
#  ('that', 'you'),
#  ('you', 'won'),
#  ('won', 'a'),
#  ('a', 'a1000'),
#  ('a1000', 'prize'),
#  ('prize', 'guaranteed'),
#  ('guaranteed', 'call'),
#  ('call', '09064012160'),
#  ('09064012160', 'claim'),
#  ('claim', 'code'),
#  ('code', 'k52'),
#  ('k52', 'valid'),
#  ('valid', '12hrs'),
#  ('12hrs', 'only'),
#  ('only', '150ppm'),
#  ('150ppm', 'you'),
#  ('you', 'are'),
#  ('are', 'a'),
#  ('a', 'winner'),
#  ('winner', 'u'),
#  ('u', 'have'),
#  ('have', 'been'),
#  ('been', 'specially'),
#  ('specially', 'selected'),
#  ('selected', '2'),
#  ('2', 'receive'),
#  ('receive', 'a1000'),
#  ('a1000', 'or'),
#  ('or', 'a'),
#  ('a', '4'),
#  ('4', 'holiday'),
#  ('holiday', 'flights'),
#  ('flights', 'inc'),
#  ('inc', 'speak'),
#  ('speak', 'to'),
#  ('to', 'a'),
#  ('a', 'live'),
#  ('live', 'operator'),
#  ('operator', '2'),
#  ('2', 'claim'),
#  ('claim', '0871277810910pmin'),
#  ('0871277810910pmin', '18'),
#  ('18', 'private'),
#  ('private', 'your'),
#  ('your', '2004'),
#  ('2004', 'account'),
#  ('account', 'statement'),
#  ('statement', 'for'),
#  ('for', '07742676969'),
#  ('07742676969', 'shows'),
#  ('shows', '786'),
#  ('786', 'unredeemed'),
#  ('unredeemed', 'bonus'),
#  ('bonus', 'points'),
#  ('points', 'to'),
#  ('to', 'claim'),
#  ('claim', 'call'),
#  ('call', '08719180248'),
#  ('08719180248', 'identifier'),
#  ('identifier', 'code'),
#  ('code', '45239'),
#  ('45239', 'expires'),
#  ('expires', 'urgent'),
#  ('urgent', 'your'),
#  ('your', 'mobile'),
#  ('mobile', 'no'),
#  ('no', 'was'),
#  ('was', 'awarded'),
#  ('awarded', 'a2000'),
#  ('a2000', 'bonus'),
#  ('bonus', 'caller'),
#  ('caller', 'prize'),
#  ('prize', 'on'),
#  ('on', '5903'),
#  ('5903', 'this'),
#  ('this', 'is'),
#  ('is', 'our'),
#  ('our', 'final'),
#  ('final', 'try'),
#  ('try', 'to'),
#  ('to', 'contact'),
#  ('contact', 'u'),
#  ('u', 'call'),
#  ('call', 'from'),
#  ('from', 'landline'),
#  ('landline', '09064019788'),
#  ('09064019788', 'box42wr29c'),
#  ('box42wr29c', '150ppm'),
#  ('150ppm', 'todays'),
#  ('todays', 'voda'),
#  ('voda', 'numbers'),
#  ('numbers', 'ending'),
#  ('ending', '7548'),
#  ('7548', 'are'),
#  ('are', 'selected'),
#  ('selected', 'to'),
#  ('to', 'receive'),
#  ('receive', 'a'),
#  ('a', '350'),
#  ('350', 'award'),
#  ('award', 'if'),
#  ('if', 'you'),
#  ('you', 'have'),
#  ('have', 'a'),
#  ('a', 'match'),
#  ('match', 'please'),
#  ('please', 'call'),
#  ('call', '08712300220'),
#  ('08712300220', 'quoting'),
#  ('quoting', 'claim'),
#  ('claim', 'code'),
#  ('code', '4041'),
#  ('4041', 'standard'),
#  ('standard', 'rates'),
#  ('rates', 'app'),
#  ('app', 'sunshine'),
#  ('sunshine', 'quiz'),
#  ('quiz', 'wkly'),
#  ('wkly', 'q'),
#  ('q', 'win'),
#  ('win', 'a'),
#  ('a', 'top'),
#  ('top', 'sony'),
#  ('sony', 'dvd'),
#  ('dvd', 'player'),
#  ('player', 'if'),
#  ('if', 'u'),
#  ('u', 'know'),
#  ('know', 'which'),
#  ('which', 'country'),
#  ('country', 'the'),
#  ('the', 'algarve'),
#  ('algarve', 'is'),
#  ('is', 'in'),
#  ('in', 'txt'),
#  ('txt', 'ansr'),
#  ('ansr', 'to'),
#  ('to', '82277'),
#  ('82277', 'a150'),
#  ('a150', 'sptyrone'),
#  ('sptyrone', 'want'),
#  ('want', '2'),
#  ('2', 'get'),
#  ('get', 'laid'),
#  ('laid', 'tonight'),
#  ('tonight', 'want'),
#  ('want', 'real'),
#  ('real', 'dogging'),
#  ('dogging', 'locations'),
#  ('locations', 'sent'),
#  ('sent', 'direct'),
#  ('direct', '2'),
#  ('2', 'ur'),
#  ('ur', 'mob'),
#  ('mob', 'join'),
#  ('join', 'the'),
#  ('the', 'uks'),
#  ('uks', 'largest'),
#  ('largest', 'dogging'),
#  ('dogging', 'network'),
#  ('network', 'bt'),
#  ('bt', 'txting'),
#  ('txting', 'gravel'),
#  ('gravel', 'to'),
#  ('to', '69888'),
#  ('69888', 'nt'),
#  ('nt', 'ec2a'),
#  ('ec2a', '31pmsg150p'),
#  ('31pmsg150p', 'youll'),
#  ('youll', 'not'),
#  ('not', 'rcv'),
#  ('rcv', 'any'),
#  ('any', 'more'),
#  ('more', 'msgs'),
#  ('msgs', 'from'),
#  ('from', 'the'),
#  ('the', 'chat'),
#  ('chat', 'svc'),
#  ('svc', 'for'),
#  ('for', 'free'),
#  ('free', 'hardcore'),
#  ('hardcore', 'services'),
#  ('services', 'text'),
#  ('text', 'go'),
#  ('go', 'to'),
#  ('to', '69988'),
#  ('69988', 'if'),
#  ('if', 'u'),
#  ('u', 'get'),
#  ('get', 'nothing'),
#  ('nothing', 'u'),
#  ('u', 'must'),
#  ('must', 'age'),
#  ('age', 'verify'),
#  ('verify', 'with'),
#  ('with', 'yr'),
#  ('yr', 'network'),
#  ('network', 'try'),
#  ('try', 'again'),
#  ('again', 'freemsg'),
#  ('freemsg', 'why'),
#  ('why', 'havent'),
#  ('havent', 'you'),
#  ('you', 'replied'),
#  ('replied', 'to'),
#  ('to', 'my'),
#  ('my', 'text'),
#  ('text', 'im'),
#  ('im', 'randy'),
#  ('randy', 'sexy'),
#  ('sexy', 'female'),
#  ('female', 'and'),
#  ('and', 'live'),
#  ('live', 'local'),
#  ('local', 'luv'),
#  ('luv', 'to'),
#  ('to', 'hear'),
#  ('hear', 'from'),
#  ('from', 'u'),
#  ('u', 'netcollex'),
#  ('netcollex', 'ltd'),
#  ('ltd', '08700621170150p'),
#  ('08700621170150p', 'per'),
#  ('per', 'msg'),
#  ('msg', 'reply'),
#  ('reply', 'stop'),
#  ('stop', 'to'),
#  ('to', 'end'),
#  ('end', 'customer'),
#  ('customer', 'service'),
#  ('service', 'annoncement'),
#  ('annoncement', 'you'),
#  ('you', 'have'),
#  ('have', 'a'),
#  ('a', 'new'),
#  ('new', 'years'),
#  ('years', 'delivery'),
#  ('delivery', 'waiting'),
#  ('waiting', 'for'),
#  ('for', 'you'),
#  ('you', 'please'),
#  ('please', 'call'),
#  ('call', '07046744435'),
#  ('07046744435', 'now'),
#  ('now', 'to'),
#  ('to', 'arrange'),
#  ('arrange', 'delivery'),
#  ('delivery', 'you'),
#  ('you', 'are'),
#  ('are', 'a'),
#  ('a', 'winner'),
#  ('winner', 'u'),
#  ('u', 'have'),
#  ('have', 'been'),
#  ('been', 'specially'),
#  ('specially', 'selected'),
#  ('selected', '2'),
#  ('2', 'receive'),
#  ('receive', 'a1000'),
#  ('a1000', 'cash'),
#  ('cash', 'or'),
#  ('or', 'a'),
#  ('a', '4'),
#  ('4', 'holiday'),
#  ('holiday', 'flights'),
#  ('flights', 'inc'),
#  ('inc', 'speak'),
#  ('speak', 'to'),
#  ('to', 'a'),
#  ('a', 'live'),
#  ('live', 'operator'),
#  ('operator', '2'),
#  ('2', 'claim'),
#  ('claim', '0871277810810'),
#  ('0871277810810', 'pls'),
#  ('pls', 'stop'),
#  ('stop', 'bootydelious'),
#  ('bootydelious', '32f'),
#  ('32f', 'is'),
#  ('is', 'inviting'),
#  ('inviting', 'you'),
#  ('you', 'to'),
#  ('to', 'be'),
#  ('be', 'her'),
#  ('her', 'friend'),
#  ('friend', 'reply'),
#  ('reply', 'yes434'),
#  ('yes434', 'or'),
#  ('or', 'no434'),
#  ('no434', 'see'),
#  ('see', 'her'),
#  ('her', 'wwwsmsacubootydelious'),
#  ('wwwsmsacubootydelious', 'stop'),
#  ('stop', 'send'),
#  ('send', 'stop'),
#  ('stop', 'frnd'),
#  ('frnd', 'to'),
#  ('to', '62468'),
#  ('62468', 'bangbabes'),
#  ('bangbabes', 'ur'),
#  ('ur', 'order'),
#  ('order', 'is'),
#  ('is', 'on'),
#  ('on', 'the'),
#  ('the', 'way'),
#  ('way', 'u'),
#  ('u', 'should'),
#  ('should', 'receive'),
#  ('receive', 'a'),
#  ('a', 'service'),
#  ('service', 'msg'),
#  ('msg', '2'),
#  ('2', 'download'),
#  ('download', 'ur'),
#  ('ur', 'content'),
#  ('content', 'if'),
#  ('if', 'u'),
#  ('u', 'do'),
#  ('do', 'not'),
#  ('not', 'goto'),
#  ('goto', 'wap'),
#  ('wap', 'bangb'),
#  ('bangb', 'tv'),
#  ('tv', 'on'),
#  ('on', 'ur'),
#  ('ur', 'mobile'),
#  ('mobile', 'internetservice'),
#  ('internetservice', 'menu'),
#  ('menu', 'urgent'),
#  ('urgent', 'we'),
#  ('we', 'are'),
#  ('are', 'trying'),
#  ('trying', 'to'),
#  ('to', 'contact'),
#  ('contact', 'you'),
#  ('you', 'last'),
#  ('last', 'weekends'),
#  ('weekends', 'draw'),
#  ('draw', 'shows'),
#  ('shows', 'that'),
#  ('that', 'you'),
#  ('you', 'have'),
#  ('have', 'won'),
#  ('won', 'a'),
#  ('a', 'a900'),
#  ('a900', 'prize'),
#  ('prize', 'guaranteed'),
#  ('guaranteed', 'call'),
#  ('call', '09061701939'),
#  ('09061701939', 'claim'),
#  ('claim', 'code'),
#  ('code', 's89'),
#  ('s89', 'valid'),
#  ('valid', '12hrs'),
#  ('12hrs', 'only'),
#  ('only', 'please'),
#  ('please', 'call'),
#  ('call', 'our'),
#  ('our', 'customer'),
#  ('customer', 'service'),
#  ('service', 'representative'),
#  ('representative', 'on'),
#  ('on', 'freephone'),
#  ('freephone', '0808'),
#  ('0808', '145'),
#  ('145', '4742'),
#  ('4742', 'between'),
#  ('between', '9am11pm'),
#  ('9am11pm', 'as'),
#  ('as', 'you'),
#  ('you', 'have'),
#  ('have', 'won'),
#  ('won', 'a'),
#  ('a', 'guaranteed'),
#  ('guaranteed', 'a1000'),
#  ('a1000', 'cash'),
#  ('cash', 'or'),
#  ('or', 'a5000'),
#  ('a5000', 'prize'),
#  ('prize', 'are'),
#  ('are', 'you'),
#  ('you', 'unique'),
#  ('unique', 'enough'),
#  ('enough', 'find'),
#  ('find', 'out'),
#  ('out', 'from'),
#  ('from', '30th'),
#  ('30th', 'august'),
#  ('august', 'wwwareyouuniquecouk'),
#  ('wwwareyouuniquecouk', '500'),
#  ('500', 'new'),
#  ('new', 'mobiles'),
#  ('mobiles', 'from'),
#  ('from', '2004'),
#  ('2004', 'must'),
#  ('must', 'go'),
#  ('go', 'txt'),
#  ('txt', 'nokia'),
#  ('nokia', 'to'),
#  ('to', 'no'),
#  ('no', '89545'),
#  ('89545', 'collect'),
#  ('collect', 'yours'),
#  ('yours', 'todayfrom'),
#  ('todayfrom', 'only'),
#  ('only', 'a1'),
#  ('a1', 'www4tcbiz'),
#  ('www4tcbiz', '2optout'),
#  ('2optout', '08718726270150gbpmtmsg18'),
#  ('08718726270150gbpmtmsg18', 'will'),
#  ('will', 'u'),
#  ('u', 'meet'),
#  ('meet', 'ur'),
#  ('ur', 'dream'),
#  ('dream', 'partner'),
#  ('partner', 'soon'),
#  ('soon', 'is'),
#  ('is', 'ur'),
#  ('ur', 'career'),
#  ('career', 'off'),
#  ('off', '2'),
#  ('2', 'a'),
#  ('a', 'flyng'),
#  ('flyng', 'start'),
#  ('start', '2'),
#  ('2', 'find'),
#  ('find', 'out'),
#  ('out', 'free'),
#  ('free', 'txt'),
#  ('txt', 'horo'),
#  ('horo', 'followed'),
#  ('followed', 'by'),
#  ('by', 'ur'),
#  ('ur', 'star'),
#  ('star', 'sign'),
#  ('sign', 'e'),
#  ('e', 'g'),
#  ('g', 'horo'),
#  ('horo', 'aries'),
#  ('aries', 'text'),
#  ('text', 'meet'),
#  ('meet', 'someone'),
#  ('someone', 'sexy'),
#  ('sexy', 'today'),
#  ('today', 'u'),
#  ('u', 'can'),
#  ('can', 'find'),
#  ('find', 'a'),
#  ('a', 'date'),
#  ('date', 'or'),
#  ('or', 'even'),
#  ('even', 'flirt'),
#  ('flirt', 'its'),
#  ('its', 'up'),
#  ('up', 'to'),
#  ('to', 'u'),
#  ('u', 'join'),
#  ('join', '4'),
#  ('4', 'just'),
#  ('just', '10p'),
#  ('10p', 'reply'),
#  ('reply', 'with'),
#  ('with', 'name'),
#  ('name', 'age'),
#  ('age', 'eg'),
#  ('eg', 'sam'),
#  ('sam', '25'),
#  ('25', '18'),
#  ('18', 'msg'),
#  ('msg', 'recdthirtyeight'),
#  ('recdthirtyeight', 'pence'),
#  ('pence', 'u'),
#  ('u', '447801259231'),
#  ('447801259231', 'have'),
#  ('have', 'a'),
#  ('a', 'secret'),
#  ('secret', 'admirer'),
#  ('admirer', 'who'),
#  ('who', 'is'),
#  ('is', 'looking'),
#  ('looking', '2'),
#  ('2', 'make'),
#  ('make', 'contact'),
#  ('contact', 'with'),
#  ('with', 'ufind'),
#  ('ufind', 'out'),
#  ('out', 'who'),
#  ('who', 'they'),
#  ('they', 'rreveal'),
#  ('rreveal', 'who'),
#  ('who', 'thinks'),
#  ('thinks', 'ur'),
#  ('ur', 'so'),
#  ('so', 'specialcall'),
#  ('specialcall', 'on'),
#  ('on', '09058094597'),
#  ('09058094597', 'congratulations'),
#  ('congratulations', 'ur'),
#  ('ur', 'awarded'),
#  ('awarded', '500'),
#  ('500', 'of'),
#  ('of', 'cd'),
#  ('cd', 'vouchers'),
#  ('vouchers', 'or'),
#  ('or', '125gift'),
#  ('125gift', 'guaranteed'),
#  ('guaranteed', 'free'),
#  ('free', 'entry'),
#  ('entry', '2'),
#  ('2', '100'),
#  ('100', 'wkly'),
#  ('wkly', 'draw'),
#  ('draw', 'txt'),
#  ('txt', 'music'),
#  ('music', 'to'),
#  ('to', '87066'),
#  ('87066', 'tncs'),
#  ('tncs', 'wwwldewcom1win150ppmx3age16'),
#  ('wwwldewcom1win150ppmx3age16', 'we'),
#  ('we', 'tried'),
#  ('tried', 'to'),
#  ('to', 'contact'),
#  ('contact', 'you'),
#  ('you', 're'),
#  ('re', 'your'),
#  ('your', 'reply'),
#  ('reply', 'to'),
#  ('to', 'our'),
#  ('our', 'offer'),
#  ('offer', 'of'),
#  ('of', 'a'),
#  ('a', 'video'),
#  ('video', 'handset'),
#  ('handset', '750'),
#  ('750', 'anytime'),
#  ('anytime', 'networks'),
#  ('networks', 'mins'),
#  ('mins', 'unlimited'),
#  ('unlimited', 'text'),
#  ('text', 'camcorder'),
#  ('camcorder', 'reply'),
#  ('reply', 'or'),
#  ('or', 'call'),
#  ('call', '08000930705'),
#  ('08000930705', 'now'),
#  ('now', 'hey'),
#  ('hey', 'i'),
#  ('i', 'am'),
#  ('am', 'really'),
#  ('really', 'horny'),
#  ('horny', 'want'),
#  ('want', 'to'),
#  ('to', 'chat'),
#  ('chat', 'or'),
#  ('or', 'see'),
#  ('see', 'me'),
#  ('me', 'naked'),
#  ('naked', 'text'),
#  ('text', 'hot'),
#  ('hot', 'to'),
#  ('to', '69698'),
#  ('69698', 'text'),
#  ('text', 'charged'),
#  ...]

# %% [markdown]
# ## Word Cloud

# %% [markdown]
# `python -m pip install --upgrade wordcloud`
#
# documentation: https://amueller.github.io/word_cloud/

# %%
from wordcloud import WordCloud
img = WordCloud(background_color='white', width=800, height=600).generate(spam_words)
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# ## Other Common Features
#
# Any NLP dataset will have domain specific features, for example: number of retweets, number of @mentions, number of upvotes, or mean time to respond to a support chat. In addition to these domain specific features, some common measures for a document are:
#
# - character count
# - word count
# - sentence count
# - stopword count
# - unique word count
# - punctuation count
# - average word length
# - average words per sentence
# - word to stopword ratio
#
# Create one or more of the above features and visualize it.

# %%
# add two new columns 'message_length' and 'word_count'

df['message_length'] = df.text.apply(len)

df['word_count'] = df.text.apply(clean).apply(str.split).apply(len)

df.head()
# Out:
#   label                                               text  message_length  \
# 0   ham  Go until jurong point, crazy.. Available only ...             111
# 1   ham                      Ok lar... Joking wif u oni...              29
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3   ham  U dun say so early hor... U c already then say...              49
# 4   ham  Nah I don't think he goes to usf, he lives aro...              61
#
#    word_count
# 0          20
# 1           6
# 2          28
# 3          11
# 4          13

# %%
sns.relplot(data = df, x = 'message_length', y = 'word_count', hue = 'label')

# %%
df.groupby('label').message_length.agg(['mean', 'median'])
# Out:
#              mean  median
# label
# ham     71.023627      52
# spam   138.866131     149

# %% [markdown]
# ## Sentiment
#
# A number indicating whether the document is positive or negative.
#
# - knowledge-based + statistical approach
# - relies on human-labelled data
#     - combination of qualitative and quantitative methods
#     - then empirically validate
# - different models for diff domains (e.g. social media vs news)
# - for social media
#     - Afinn ([github](https://github.com/fnielsen/afinn) + [whitepaper](http://www2.imm.dtu.dk/pubdb/edoc/imm6006.pdf))
#     - Vader ([github](https://github.com/cjhutto/vaderSentiment) + [whitepaper](http://comp.social.gatech.edu/papers/icwsm14.vader.hutto.pdf)) `nltk.sentiment.vader.SentimentIntensityAnalyzer`. Pre-trained sentiment analyzer (**V**alence **A**ware **D**ictionary and s**E**ntiment **R**easoner).)

# %% [markdown]
# From your terminal:
# `python -c 'import nltk;nltk.download("vader_lexicon")'`

# %%
import nltk.sentiment

sia = nltk.sentiment.SentimentIntensityAnalyzer()
sia.polarity_scores('He is really good')
# Out:
# {'neg': 0.0, 'neu': 0.484, 'pos': 0.516, 'compound': 0.4927}

# %%
sia.polarity_scores('He is really good!!!')
# Out:
# {'neg': 0.0, 'neu': 0.424, 'pos': 0.576, 'compound': 0.6211}

# %%
sia.polarity_scores('He is REALLY good')
# Out:
# {'neg': 0.0, 'neu': 0.433, 'pos': 0.567, 'compound': 0.6028}

# %%
sia.polarity_scores('He is very good!!!')
# Out:
# {'neg': 0.0, 'neu': 0.424, 'pos': 0.576, 'compound': 0.6211}

# %%
sia.polarity_scores('The food is good but service is slow')
# Out:
# {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.2382}

# %%
sia.polarity_scores('He is good :-)')
# Out:
# {'neg': 0.0, 'neu': 0.278, 'pos': 0.722, 'compound': 0.6369}

# %%
sia.polarity_scores('The food SUX')
# Out:
# {'neg': 0.618, 'neu': 0.382, 'pos': 0.0, 'compound': -0.4995}

# %% [markdown]
# Things that can influence Sentiment Score:
# 1. Punctuations. Can increase the intensity
# 2. Capitalization. Can increase the intensity
# 3. Degree modifiers
# 4. Conjunctions
#
# It can handle Emojis and slangs

# %% [markdown]
# Apply this to the text message data

# %%
df['sentiment'] = df.text.apply(lambda doc: sia.polarity_scores(doc)['compound'])
df
# Out:
#      label                                               text  message_length  \
# 0      ham  Go until jurong point, crazy.. Available only ...             111
# 1      ham                      Ok lar... Joking wif u oni...              29
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3      ham  U dun say so early hor... U c already then say...              49
# 4      ham  Nah I don't think he goes to usf, he lives aro...              61
# ...    ...                                                ...             ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...             161
# 5568   ham              Will Ì_ b going to esplanade fr home?              37
# 5569   ham  Pity, * was in mood for that. So...any other s...              57
# 5570   ham  The guy did some bitching but I acted like i'd...             125
# 5571   ham                         Rofl. Its true to its name              26
#
#       word_count  sentiment
# 0             20     0.6249
# 1              6     0.4767
# 2             28     0.7964
# 3             11     0.0000
# 4             13    -0.1027
# ...          ...        ...
# 5567          30     0.8805
# 5568           8     0.0000
# 5569           9    -0.2960
# 5570          26     0.8934
# 5571           6     0.7579
#
# [5572 rows x 5 columns]

# %%
# is the mean and median values of sentiment score different for ham vs spam?
df.groupby('label').sentiment.agg(['mean','median'])
# Out:
#            mean  median
# label
# ham    0.152218  0.0000
# spam   0.436018  0.6107

# %%
#plot message_length vs sentiment and hue by label
sns.relplot(data = df, x = 'message_length', y = 'sentiment', hue = 'label')

# %%
# is the distribution for sentiment different for ham vs spam
sns.kdeplot(df[df.label == 'ham'].sentiment, label = 'ham')
sns.kdeplot(df[df.label == 'spam'].sentiment, label = 'spam');

# %%
# Bivariate KDE plot for message_length vs sentiment score 
sns.kdeplot(df[df.label == 'ham'].message_length,df[df.label == 'ham'].sentiment, levels = 30, shade = True )
sns.kdeplot(df[df.label == 'spam'].message_length,df[df.label == 'spam'].sentiment, levels = 30, shade = True, alpha = 0.5 )
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='message_length', ylabel='sentiment'>

# %% [markdown]
# ## More Resources
#
# - [kaggle wikipedia movie plots](https://www.kaggle.com/jrobischon/wikipedia-movie-plots)
#     - Suggestion: narrow to top n genres that aren't unknown
# - [wikitable extractor](https://wikitable2csv.ggor.de/) (Try with, e.g. [helicopter prison escapes](https://en.wikipedia.org/wiki/List_of_helicopter_prison_escapes))
# - [Textblob library](https://textblob.readthedocs.io/en/dev/)
